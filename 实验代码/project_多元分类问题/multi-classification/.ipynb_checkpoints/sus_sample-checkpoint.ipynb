# %%
import copy
import random
import operator
import re
import math
import gensim

import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns

from functools import reduce
from collections import Counter

# % matplotlib inline
# sns.set()
# Out:
# c:\users\小柒\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
stopwords = [
    "i",          "me",         "my",         "myself",     "we",        
    "our",        "ours",       "ourselves",  "you",        "your",      
    "yours",      "yourself",   "yourselves", "he",         "him",       
    "his",        "himself",    "she",        "her",        "hers",      
    "herself",    "it",         "its",        "itself",     "they",      
    "them",       "their",      "theirs",     "themselves", "what",      
    "which",      "who",        "whom",       "this",       "that",      
    "these",      "those",      "am",         "is",         "are",       
    "was",        "were",       "be",         "been",       "being",     
    "have",       "has",        "had",        "having",     "do",        
    "does",       "did",        "doing",      "would",      "should",    
    "could",      "ought",      "i'm",        "you're",     "he's",      
    "she's",      "it's",       "we're",      "they're",    "i've",      
    "you've",     "we've",      "they've",    "i'd",        "you'd",     
    "he'd",       "she'd",      "we'd",       "they'd",     "i'll",      
    "you'll",     "he'll",      "she'll",     "we'll",      "they'll",   
    "isn't",      "aren't",     "wasn't",     "weren't",    "hasn't",    
    "haven't",    "hadn't",     "doesn't",    "don't",      "didn't",    
    "won't",      "wouldn't",   "shan't",     "shouldn't",  "can't",     
    "cannot",     "couldn't",   "mustn't",    "let's",      "that's",    
    "who's",      "what's",     "here's",     "there's",    "when's",    
    "where's",    "why's",      "how's",      "a",          "an",        
    "the",        "and",        "but",        "if",         "or",        
    "because",    "as",         "until",      "while",      "of",        
    "at",         "by",         "for",        "with",       "about",     
    "against",    "between",    "into",       "through",    "during",    
    "before",     "after",      "above",      "below",      "to",        
    "from",       "up",         "down",       "in",         "out",       
    "on",         "off",        "over",       "under",      "again",     
    "further",    "then",       "once",       "here",       "there",     
    "when",       "where",      "why",        "how",        "all",       
    "any",        "both",       "each",       "few",        "more",      
    "most",       "other",      "some",       "such",       "no",        
    "nor",        "not",        "only",       "own",        "same",      
    "so",         "than",       "too",        "very",       "will"
]

# %%
def single(string):
    li = list(string)
    i =[0]+list(filter(lambda x:li[x]!=li[x-1],range(1,len(li))))
    return ''.join([li[x] for x in i])
def clearstring(string):
    string = re.sub('<sssss>' , ' ', string)
#     string = re.sub('- *[lr]rb *-', ' ', string)
#     string = re.sub('(^| )http:[^ ]+', ' ', string)
#     string = re.sub('(^| )[A-Za-z]( |$)', ' ', string)
#     string = re.sub('(^| )\'[^ ]+', ' ', string)
#     string = re.sub('(^| )n\'t ', ' ', string)
    string = re.sub('[^A-Za-z !?/]+', '', string)
#     string = re.sub('(^| )[A-Za-z]( |$)', ' ', string)
#     string = re.sub('/', ' ', string)
#     string = string.split()
#     # string = set(string) - set(stopwords)
#     _str = []
#     for x in string:
#         if len(x) > 7:
#             x = single(x)
#         if x not in stopwords: 
#             _str += [x]
#     # string = [single(x) for x in string if x not in stopwords]
#     string = ' '.join(_str)
    return string

# %%
def readDatacont(fpath):
    label = []
    Dataset = [] 
    table = {'LOW':{'count': Counter(), 'word_id':{}}, 
             'MID':{'count': Counter(), 'word_id':{}}, 
             'HIG':{'count': Counter(), 'word_id':{}}}
    file = open(fpath, encoding='UTF-8')
    i = 0
    for line in file:
        l = line.split('\t\t')
        label.append(l[0])
        words = clearstring(l[1].strip()).split()
        for wd in words:
            try:
                table[l[0]]['word_id'][wd] += [i]
            except:
                table[l[0]]['word_id'][wd] = [i]
        words_count = Counter(words)
        table[l[0]]['count'] += words_count
        Dataset.append(words_count)
        i += 1
    file.close()
    return label, Dataset, table
def readTest(fpath):
    Dataset = [] 
    file = open(fpath, encoding='UTF-8')
    for line in file:
        l = line.split('\t\t')
        words = Counter(clearstring(l[1].strip()).split())
        Dataset.append(words)
    file.close()
    return Dataset

# %%
label, train_set, table = readDatacont('MulLabelTrain.ss')
test_set = readTest('MulLabelTest.ss')
vlabel, valid_set, _ = readDatacont('SmallValid.ss')

# %%
all_counter = table['MID']['count'] + table['LOW']['count'] + table['HIG']['count']

# %%
l = sorted(all_counter.items(),key=lambda x:x[1], reverse=True)

# %%
LMH = {}
for key in all_counter.keys():
    count = [table['LOW']['count'][key], table['MID']['count'][key], table['HIG']['count'][key]]
    count = np.array(count)
    LMH[key] = {
        'count': count,
        'importance': count.var()/count.sum()
    }
l = sorted(LMH.items(), key=lambda x:x[1]['importance'], reverse=True)

# %%
sus_sample = [0]*len(train_set)
name = {0:'LOW',1:'MID',2:'HIG'}
for wd in l[:7000]:
    label_i = name[wd[1]['count'].argmin()]
    word_ = table[label_i]['word_id']
    if wd[0] in word_:
        for sid in set(word_[wd[0]]):
            sus_sample[sid] += 1

# %%
sus_alpha = 60
sample_remain = list(filter(lambda x: x[1]<sus_alpha, zip(range(len(train_set)), sus_sample)))

# %%
len(train_set)
# Out:
# 62522

# %%
sample_remain_id = list(map(lambda x: x[0], sample_remain))
new_trainset = list(map(lambda x: train_set[x],sample_remain_id))
new_label = list(map(lambda x:label[x], sample_remain_id))

# %%
new_trainset[:100]
# Out:
# [Counter({'?': 1,
#           'all': 1,
#           'already': 1,
#           'am': 1,
#           'and': 8,
#           'around': 4,
#           'at': 1,
#           'avocado': 1,
#           'away': 1,
#           'back': 1,
#           'baked': 1,
#           'be': 2,
#           'because': 1,
#           'been': 1,
#           'bo': 1,
#           'boy': 1,
#           'boyfriend': 1,
#           'breaded': 1,
#           'breakfast': 2,
#           'breast': 1,
#           'brick': 1,
#           'burrito': 2,
#           'cajun': 1,
#           'came': 4,
#           'carne': 2,
#           'chicken': 3,
#           'coffee': 2,
#           'come': 1,
#           'commented': 1,
#           'day': 1,
#           'eggs': 2,
#           'employee': 1,
#           'even': 1,
#           'fat': 1,
#           'finally': 1,
#           'food': 1,
#           'front': 1,
#           'good': 2,
#           'got': 1,
#           'green': 1,
#           'had': 2,
#           'half': 1,
#           'hand': 1,
#           'have': 1,
#           'how': 1,
#           'in': 1,
#           'is': 1,
#           'it': 2,
#           'kids': 1,
#           'like': 2,
#           'lot': 1,
#           'many': 1,
#           'meals': 1,
#           'meat': 1,
#           'menu': 2,
#           'minutes': 1,
#           'mixed': 2,
#           'must': 1,
#           'my': 4,
#           'new': 1,
#           'newamerican': 1,
#           'next': 1,
#           'no': 2,
#           'of': 3,
#           'on': 4,
#           'one': 1,
#           'or': 2,
#           'ordered': 2,
#           'our': 2,
#           'out': 5,
#           'people': 1,
#           'pepper': 1,
#           'pieces': 1,
#           'pita': 1,
#           'plate': 1,
#           'real': 1,
#           'restaurant': 1,
#           'right': 1,
#           'saying': 1,
#           'scrambled': 1,
#           'seasoned': 1,
#           'seated': 1,
#           'side': 1,
#           'sitting': 1,
#           'so': 1,
#           'some': 1,
#           'something': 1,
#           'style': 2,
#           'sunday': 2,
#           'syrup': 1,
#           'task': 1,
#           'the': 8,
#           'them': 1,
#           'then': 1,
#           'there': 1,
#           'they': 2,
#           'think': 1,
#           'to': 3,
#           'toasted': 1,
#           'too': 1,
#           'took': 1,
#           'tortilla': 1,
#           'training': 1,
#           'trying': 1,
#           'two': 1,
#           'type': 1,
#           'us': 1,
#           'waffle': 2,
#           'waffles': 1,
#           'wandering': 1,
#           'was': 6,
#           'we': 2,
#           'went': 1,
#           'were': 2,
#           'with': 4,
#           'wont': 1,
#           'wrap': 1}),
#  Counter({'ambiance': 1,
#           'and': 2,
#           'any': 2,
#           'appetizer': 1,
#           'artichoke': 1,
#           'at': 1,
#           'authentic': 1,
#           'big': 1,
#           'blah': 1,
#           'bland': 1,
#           'chandler': 1,
#           'convinced': 1,
#           'did': 1,
#           'dip': 1,
#           'disappointed': 1,
#           'discover': 1,
#           'dish': 1,
#           'do': 1,
#           'everywhere': 1,
#           'family': 1,
#           'felt': 1,
#           'food': 2,
#           'for': 1,
#           'friendly': 1,
#           'getting': 1,
#           'go': 3,
#           'guess': 1,
#           'have': 1,
#           'hint': 1,
#           'idea': 1,
#           'inside': 1,
#           'is': 2,
#           'it': 1,
#           'italian': 3,
#           'just': 1,
#           'kid': 1,
#           'kind': 1,
#           'like': 1,
#           'literally': 1,
#           'mall': 1,
#           'marinara': 1,
#           'meatballs': 1,
#           'menu': 1,
#           'money': 1,
#           'never': 1,
#           'nice': 1,
#           'no': 1,
#           'nothing': 2,
#           'of': 3,
#           'old': 1,
#           'or': 3,
#           'oregano': 1,
#           'oriented': 1,
#           'other': 1,
#           'palette': 1,
#           'people': 1,
#           'place': 1,
#           'same': 1,
#           'sauce': 1,
#           'save': 1,
#           'so': 1,
#           'spaghetti': 2,
#           'special': 1,
#           'spices': 1,
#           'spiciness': 1,
#           'sucks': 1,
#           'taste': 1,
#           'the': 8,
#           'thing': 1,
#           'this': 1,
#           'to': 3,
#           'very': 1,
#           'was': 2,
#           'whatsoever': 1,
#           'where': 1,
#           'whole': 1,
#           'with': 1,
#           'your': 3}),
#  Counter({'about': 2,
#           'and': 6,
#           'any': 1,
#           'around': 1,
#           'asked': 1,
#           'average': 1,
#           'awesome': 1,
#           'bar': 2,
#           'bartenders': 1,
#           'be': 1,
#           'been': 1,
#           'bubble': 1,
#           'but': 1,
#           'carlos': 1,
#           'chandeliers': 1,
#           'comes': 1,
#           'coming': 1,
#           'cool': 1,
#           'couple': 1,
#           'disappointed': 1,
#           'dj': 3,
#           'drinks': 1,
#           'each': 1,
#           'enough': 1,
#           'explained': 1,
#           'felt': 1,
#           'for': 2,
#           'friday': 1,
#           'grandma': 1,
#           'had': 1,
#           'has': 2,
#           'have': 3,
#           'historical': 1,
#           'hot': 1,
#           'hotel': 1,
#           'huge': 1,
#           'hung': 1,
#           'in': 4,
#           'inside': 2,
#           'is': 2,
#           'it': 4,
#           'lamp': 1,
#           'light': 1,
#           'like': 3,
#           'live': 1,
#           'lively': 1,
#           'living': 1,
#           'location': 1,
#           'looks': 1,
#           'min': 1,
#           'more': 1,
#           'much': 1,
#           'music': 2,
#           'my': 1,
#           'night': 2,
#           'no': 1,
#           'not': 2,
#           'of': 1,
#           'on': 2,
#           'or': 2,
#           'organized': 1,
#           'out': 1,
#           'part': 1,
#           'pink': 1,
#           'place': 1,
#           'pm': 1,
#           'potential': 1,
#           'prices': 1,
#           'quiet': 1,
#           'room': 1,
#           'san': 1,
#           'section': 1,
#           'so': 2,
#           'specific': 1,
#           'still': 1,
#           'sure': 1,
#           'that': 3,
#           'the': 7,
#           'there': 1,
#           'they': 2,
#           'this': 2,
#           'time': 1,
#           'to': 2,
#           'updated': 1,
#           'very': 1,
#           'vip': 1,
#           'was': 2,
#           'we': 3,
#           'weekends': 1,
#           'went': 1,
#           'were': 2,
#           'when': 1,
#           'while': 1,
#           'with': 2,
#           'within': 1}),
#  Counter({'!': 1,
#           'all': 1,
#           'also': 1,
#           'and': 4,
#           'are': 1,
#           'as': 1,
#           'away': 1,
#           'been': 1,
#           'best': 1,
#           'better': 1,
#           'brick': 1,
#           'chop': 2,
#           'cooking': 1,
#           'cooler': 1,
#           'could': 2,
#           'good': 1,
#           'had': 2,
#           'have': 1,
#           'it': 5,
#           'kitchen': 1,
#           'larger': 1,
#           'meatball': 1,
#           'nice': 1,
#           'of': 2,
#           'on': 2,
#           'one': 1,
#           'open': 1,
#           'ordered': 2,
#           'our': 1,
#           'oven': 1,
#           'packed': 1,
#           'pizza': 1,
#           'pizzas': 1,
#           'popular': 1,
#           'portion': 1,
#           'pretty': 1,
#           'refreshing': 1,
#           'reservation': 1,
#           'right': 1,
#           'salad': 1,
#           'salads': 1,
#           'sat': 1,
#           'see': 1,
#           'service': 1,
#           'side': 1,
#           'since': 3,
#           'smaller': 1,
#           'split': 2,
#           'strong': 1,
#           'sunday': 1,
#           'the': 5,
#           'they': 2,
#           'to': 1,
#           'us': 1,
#           'very': 1,
#           'was': 8,
#           'way': 1,
#           'we': 4,
#           'which': 1,
#           'wine': 1,
#           'wish': 1}),
#  Counter({'!': 1,
#           'and': 1,
#           'chefs': 1,
#           'dish': 1,
#           'favorite': 1,
#           'good': 1,
#           'huge': 1,
#           'my': 1,
#           'omg': 1,
#           'servings': 1,
#           'shrimp': 1,
#           'so': 1,
#           'specialty': 1,
#           'the': 1,
#           'us': 1}),
#  Counter({'!': 1,
#           'again': 1,
#           'all': 2,
#           'and': 3,
#           'are': 6,
#           'around': 1,
#           'at': 1,
#           'be': 2,
#           'beans': 1,
#           'beer': 1,
#           'burritos': 1,
#           'called': 1,
#           'come': 1,
#           'counter': 1,
#           'deal': 1,
#           'eat': 1,
#           'eating': 1,
#           'else': 1,
#           'experience': 1,
#           'feel': 1,
#           'for': 2,
#           'forever': 1,
#           'go': 1,
#           'good': 2,
#           'here': 2,
#           'huge': 1,
#           'if': 1,
#           'important': 1,
#           'is': 2,
#           'just': 2,
#           'know': 1,
#           'like': 1,
#           'lol': 1,
#           'looking': 1,
#           'magic': 1,
#           'makes': 1,
#           'many': 1,
#           'me': 1,
#           'no': 1,
#           'number': 1,
#           'order': 1,
#           'place': 1,
#           'plates': 1,
#           'real': 1,
#           'restaurant': 1,
#           'rice': 1,
#           'salsas': 1,
#           'serve': 1,
#           'server': 1,
#           'so': 2,
#           'somewhere': 1,
#           'tempting': 1,
#           'that': 1,
#           'the': 5,
#           'then': 1,
#           'there': 1,
#           'they': 1,
#           'things': 1,
#           'this': 2,
#           'to': 4,
#           'very': 1,
#           'wait': 1,
#           'waiting': 2,
#           'which': 1,
#           'while': 1,
#           'will': 1,
#           'with': 1,
#           'you': 5,
#           'your': 1}),
#  Counter({'?': 1,
#           '???': 1,
#           '????': 1,
#           'about': 1,
#           'all': 1,
#           'and': 3,
#           'asada': 3,
#           'at': 1,
#           'back': 2,
#           'beers': 1,
#           'best': 1,
#           'better': 1,
#           'big': 1,
#           'bought': 1,
#           'btw': 1,
#           'burrito': 1,
#           'burritos': 1,
#           'but': 1,
#           'bux': 1,
#           'carne': 3,
#           'ceviche': 2,
#           'do': 1,
#           'dude': 1,
#           'dunno': 1,
#           'expensive': 1,
#           'for': 1,
#           'give': 1,
#           'go': 2,
#           'gon': 1,
#           'good': 2,
#           'guess': 2,
#           'if': 1,
#           'is': 1,
#           'it': 4,
#           'its': 1,
#           'just': 1,
#           'like': 2,
#           'means': 1,
#           'meat': 1,
#           'na': 1,
#           'next': 2,
#           'no': 1,
#           'not': 1,
#           'only': 1,
#           'order': 2,
#           'places': 1,
#           'pricey': 1,
#           'right': 1,
#           'see': 1,
#           'shop': 1,
#           'so': 1,
#           'star': 1,
#           'taco': 1,
#           'tacos': 1,
#           'that': 2,
#           'the': 2,
#           'thought': 1,
#           'time': 2,
#           'to': 1,
#           'too': 2,
#           'usually': 1,
#           'very': 1,
#           'was': 3,
#           'we': 2,
#           'yea': 1,
#           'yes': 1}),
#  Counter({'!!!': 1,
#           '?': 2,
#           'able': 1,
#           'about': 2,
#           'afternoon': 1,
#           'agua': 2,
#           'all': 2,
#           'alone': 1,
#           'an': 2,
#           'and': 14,
#           'animal': 1,
#           'arrived': 1,
#           'asada': 1,
#           'asked': 1,
#           'at': 1,
#           'be': 1,
#           'because': 2,
#           'bill': 1,
#           'bite': 1,
#           'bleh': 1,
#           'boyfriend': 1,
#           'breakfast': 1,
#           'but': 2,
#           'calories': 1,
#           'carne': 1,
#           'cavalier': 1,
#           'chicken': 5,
#           'chips': 4,
#           'chop': 1,
#           'claim': 1,
#           'de': 2,
#           'decided': 3,
#           'did': 1,
#           'disgusted': 1,
#           'do': 1,
#           'dog': 1,
#           'dogs': 1,
#           'done': 1,
#           'drive': 1,
#           'even': 1,
#           'every': 1,
#           'everywhere': 1,
#           'excited': 1,
#           'fame': 1,
#           'find': 1,
#           'flavor': 1,
#           'food': 1,
#           'for': 2,
#           'fried': 4,
#           'giant': 2,
#           'going': 2,
#           'good': 1,
#           'got': 3,
#           'great': 1,
#           'grossed': 1,
#           'had': 1,
#           'half': 3,
#           'ham': 1,
#           'have': 1,
#           'heard': 1,
#           'home': 1,
#           'honestly': 1,
#           'hot': 2,
#           'how': 1,
#           'huge': 2,
#           'in': 4,
#           'ingested': 1,
#           'ingesting': 1,
#           'inside': 1,
#           'into': 1,
#           'is': 2,
#           'it': 7,
#           'joy': 1,
#           'just': 3,
#           'king': 1,
#           'know': 2,
#           'knows': 1,
#           'late': 1,
#           'least': 1,
#           'left': 1,
#           'let': 1,
#           'like': 1,
#           'literally': 1,
#           'lol': 1,
#           'lot': 1,
#           'man': 1,
#           'many': 1,
#           'meat': 1,
#           'mexican': 1,
#           'my': 1,
#           'no': 3,
#           'north': 1,
#           'not': 1,
#           'of': 1,
#           'off': 2,
#           'oh': 1,
#           'ok': 3,
#           'on': 1,
#           'once': 1,
#           'one': 1,
#           'only': 2,
#           'order': 1,
#           'ordered': 2,
#           'our': 2,
#           'out': 2,
#           'phoenix': 1,
#           'pia': 2,
#           'place': 1,
#           'plus': 1,
#           'pork': 1,
#           'portion': 1,
#           'posted': 1,
#           'potato': 1,
#           'realized': 1,
#           'said': 1,
#           'salsa': 1,
#           'sandwich': 4,
#           'server': 1,
#           'she': 1,
#           'shredded': 1,
#           'situation': 1,
#           'so': 6,
#           'split': 2,
#           'sprite': 1,
#           'start': 1,
#           'started': 1,
#           'steak': 2,
#           'that': 3,
#           'the': 13,
#           'then': 5,
#           'there': 2,
#           'they': 1,
#           'thing': 1,
#           'think': 1,
#           'this': 4,
#           'thought': 1,
#           'threw': 1,
#           'to': 10,
#           'took': 1,
#           'top': 2,
#           'torta': 2,
#           'tortilla': 1,
#           'travis': 1,
#           'tried': 1,
#           'up': 1,
#           'us': 1,
#           'voiced': 1,
#           'vomit': 1,
#           'vs': 1,
#           'walked': 1,
#           'was': 8,
#           'way': 1,
#           'we': 6,
#           'weird': 1,
#           'went': 1,
#           'what': 1,
#           'when': 1,
#           'who': 1,
#           'whole': 1,
#           'with': 1}),
#  Counter({'!': 1,
#           '!!': 1,
#           '??': 1,
#           '???': 1,
#           'all': 1,
#           'and': 6,
#           'anymore': 1,
#           'anyways': 1,
#           'bar': 1,
#           'bartender': 1,
#           'be': 1,
#           'bungalow': 1,
#           'christina': 1,
#           'comfortable': 1,
#           'dining': 1,
#           'does': 1,
#           'employee': 1,
#           'employees': 2,
#           'every': 1,
#           'example': 1,
#           'experience': 1,
#           'extremely': 1,
#           'for': 2,
#           'friendly': 1,
#           'fun': 1,
#           'funny': 1,
#           'get': 1,
#           'getting': 1,
#           'girl': 1,
#           'good': 1,
#           'great': 1,
#           'greeted': 1,
#           'grill': 1,
#           'happy': 1,
#           'has': 1,
#           'in': 1,
#           'interacted': 1,
#           'into': 1,
#           'is': 2,
#           'job': 1,
#           'lee': 1,
#           'literally': 1,
#           'look': 1,
#           'made': 1,
#           'more': 1,
#           'much': 1,
#           'off': 1,
#           'ok': 1,
#           'other': 1,
#           'our': 2,
#           'out': 1,
#           'outgoing': 1,
#           'pearl': 1,
#           'place': 1,
#           'places': 1,
#           'price': 1,
#           'really': 1,
#           'scottsdale': 1,
#           'server': 1,
#           'shout': 1,
#           'smiling': 1,
#           'snobby': 1,
#           'so': 2,
#           'sushi': 2,
#           'than': 1,
#           'that': 5,
#           'the': 2,
#           'their': 1,
#           'there': 1,
#           'they': 1,
#           'this': 1,
#           'to': 2,
#           'tolerable': 1,
#           'topic': 1,
#           'walked': 1,
#           'was': 2,
#           'we': 1,
#           'were': 1,
#           'who': 1,
#           'with': 1}),
#  Counter({'again': 1,
#           'and': 1,
#           'appreciated': 1,
#           'barros': 3,
#           'being': 1,
#           'better': 1,
#           'bomb': 1,
#           'but': 1,
#           'by': 1,
#           'close': 1,
#           'crust': 1,
#           'cut': 1,
#           'eat': 1,
#           'for': 1,
#           'forgiving': 1,
#           'good': 2,
#           'if': 1,
#           'im': 1,
#           'instead': 1,
#           'into': 1,
#           'is': 1,
#           'it': 2,
#           'like': 1,
#           'morning': 1,
#           'next': 1,
#           'not': 1,
#           'of': 2,
#           'only': 1,
#           'or': 1,
#           'order': 1,
#           'ordered': 1,
#           'pizza': 1,
#           'place': 1,
#           'pretty': 1,
#           'really': 2,
#           'sauce': 1,
#           'since': 1,
#           'slices': 1,
#           'so': 2,
#           'spinato': 1,
#           'squares': 1,
#           'tasted': 1,
#           'that': 1,
#           'the': 3,
#           'there': 1,
#           'they': 1,
#           'this': 2,
#           'though': 1,
#           'unmicrowaved': 1,
#           'usually': 1,
#           'venezia': 1,
#           'was': 2,
#           'weekend': 1}),
#  Counter({'about': 1,
#           'all': 1,
#           'and': 3,
#           'away': 1,
#           'bar': 1,
#           'be': 1,
#           'being': 1,
#           'comfortable': 1,
#           'conversation': 1,
#           'crappy': 1,
#           'dated': 1,
#           'decor': 2,
#           'excellent': 1,
#           'fantastic': 1,
#           'feel': 3,
#           'few': 1,
#           'food': 2,
#           'format': 1,
#           'funny': 1,
#           'glasses': 1,
#           'healthy': 1,
#           'in': 3,
#           'is': 2,
#           'kind': 1,
#           'like': 1,
#           'loud': 1,
#           'made': 2,
#           'making': 1,
#           'me': 2,
#           'might': 1,
#           'mirrors': 1,
#           'of': 3,
#           'over': 1,
#           'part': 1,
#           'place': 1,
#           'pour': 1,
#           'presentation': 1,
#           'scarface': 1,
#           'served': 1,
#           'service': 1,
#           'sitting': 1,
#           'tables': 1,
#           'the': 7,
#           'they': 1,
#           'too': 1,
#           'town': 1,
#           'very': 1,
#           'was': 2,
#           'wine': 1,
#           'without': 1,
#           'worrying': 1,
#           'you': 1}),
#  Counter({'!': 1,
#           '??': 1,
#           '???': 1,
#           'about': 1,
#           'adding': 1,
#           'again': 1,
#           'all': 1,
#           'allow': 1,
#           'although': 1,
#           'and': 4,
#           'anyone': 1,
#           'aunt': 2,
#           'average': 1,
#           'by': 1,
#           'came': 1,
#           'canned': 1,
#           'chicken': 4,
#           'chilada': 2,
#           'chile': 2,
#           'company': 1,
#           'dad': 1,
#           'dare': 1,
#           'dish': 2,
#           'does': 1,
#           'down': 1,
#           'dry': 1,
#           'ducks': 1,
#           'fail': 1,
#           'flagged': 1,
#           'grossed': 1,
#           'her': 1,
#           'in': 1,
#           'inside': 2,
#           'it': 3,
#           'jerky': 1,
#           'just': 1,
#           'kinda': 1,
#           'like': 3,
#           'looked': 2,
#           'make': 1,
#           'me': 1,
#           'mexican': 1,
#           'my': 3,
#           'near': 1,
#           'never': 2,
#           'norma': 1,
#           'nothing': 1,
#           'or': 1,
#           'ordered': 1,
#           'our': 1,
#           'out': 2,
#           'over': 1,
#           'own': 1,
#           'place': 2,
#           'relleno': 2,
#           'ruin': 1,
#           'said': 1,
#           'salsa': 1,
#           'seriously': 1,
#           'server': 1,
#           'she': 1,
#           'shocked': 1,
#           'simple': 2,
#           'so': 1,
#           'spend': 2,
#           'stuffed': 1,
#           'sweet': 1,
#           'taquitos': 1,
#           'that': 2,
#           'the': 4,
#           'theirs': 1,
#           'they': 1,
#           'this': 1,
#           'to': 1,
#           'was': 6,
#           'way': 1,
#           'what': 2,
#           'while': 1,
#           'who': 1,
#           'will': 1,
#           'with': 1,
#           'would': 2,
#           'you': 1}),
#  Counter({'actually': 1,
#           'alcoholic': 1,
#           'also': 1,
#           'am': 1,
#           'amazing': 1,
#           'and': 8,
#           'another': 1,
#           'anways': 1,
#           'asked': 1,
#           'asparagus': 1,
#           'at': 1,
#           'be': 1,
#           'been': 1,
#           'better': 1,
#           'beverage': 1,
#           'bill': 1,
#           'bowl': 1,
#           'bucks': 1,
#           'burger': 1,
#           'but': 3,
#           'calamari': 2,
#           'came': 1,
#           'chopped': 1,
#           'could': 1,
#           'crusted': 1,
#           'dark': 1,
#           'delicious': 1,
#           'did': 1,
#           'different': 1,
#           'dish': 3,
#           'dishes': 1,
#           'do': 1,
#           'down': 1,
#           'each': 1,
#           'enjoy': 1,
#           'entrees': 1,
#           'far': 1,
#           'filling': 1,
#           'fish': 1,
#           'for': 4,
#           'getting': 1,
#           'go': 1,
#           'got': 2,
#           'hand': 1,
#           'has': 1,
#           'have': 2,
#           'her': 3,
#           'his': 1,
#           'hours': 1,
#           'if': 2,
#           'inside': 1,
#           'is': 1,
#           'it': 7,
#           'just': 2,
#           'later': 1,
#           'lazy': 1,
#           'like': 1,
#           'littler': 1,
#           'looked': 1,
#           'macadamia': 1,
#           'mahimahi': 1,
#           'mashed': 1,
#           'maybe': 1,
#           'me': 1,
#           'my': 3,
#           'need': 1,
#           'nice': 1,
#           'no': 1,
#           'not': 1,
#           'of': 7,
#           'okay': 1,
#           'on': 2,
#           'one': 1,
#           'only': 1,
#           'ordered': 2,
#           'other': 1,
#           'our': 3,
#           'personality': 1,
#           'place': 1,
#           'plans': 1,
#           'potato': 1,
#           'potatoes': 1,
#           'quiet': 1,
#           'really': 1,
#           'recipe': 1,
#           'recreate': 1,
#           'red': 2,
#           'return': 1,
#           'rice': 1,
#           'same': 2,
#           'sampler': 1,
#           'sauce': 1,
#           'server': 2,
#           'serving': 1,
#           'she': 4,
#           'sitting': 1,
#           'slices': 1,
#           'so': 1,
#           'some': 1,
#           'spicy': 1,
#           'started': 1,
#           'sticks': 1,
#           'sure': 1,
#           'sweet': 1,
#           'the': 9,
#           'they': 1,
#           'this': 4,
#           'thought': 2,
#           'time': 1,
#           'to': 3,
#           'told': 2,
#           'too': 1,
#           'top': 1,
#           'total': 1,
#           'travis': 3,
#           'tried': 1,
#           'try': 2,
#           'us': 2,
#           'wanted': 1,
#           'wanting': 1,
#           'was': 7,
#           'we': 5,
#           'weekend': 2,
#           'went': 1,
#           'were': 1,
#           'while': 1,
#           'will': 1,
#           'with': 5,
#           'write': 1}),
#  Counter({'!': 3,
#           'do': 1,
#           'employees': 1,
#           'enjoyable': 1,
#           'favorite': 1,
#           'friendly': 1,
#           'gelato': 1,
#           'grout': 1,
#           'hannah': 1,
#           'however': 1,
#           'is': 1,
#           'its': 1,
#           'make': 1,
#           'miss': 1,
#           'my': 2,
#           'place': 1,
#           'scooper': 1,
#           'super': 1,
#           'that': 1,
#           'the': 1,
#           'this': 1,
#           'visits': 1,
#           'yummy': 1}),
#  Counter({'?': 2,
#           '???': 1,
#           'about': 1,
#           'again': 1,
#           'all': 2,
#           'and': 3,
#           'are': 1,
#           'around': 1,
#           'as': 1,
#           'athelets': 1,
#           'be': 1,
#           'beef': 2,
#           'been': 1,
#           'bf': 1,
#           'bush': 1,
#           'but': 1,
#           'came': 1,
#           'cheese': 1,
#           'dead': 1,
#           'diners': 1,
#           'dish': 1,
#           'enchilada': 1,
#           'etc': 1,
#           'even': 1,
#           'expect': 1,
#           'famous': 1,
#           'food': 1,
#           'glad': 1,
#           'go': 1,
#           'going': 1,
#           'good': 1,
#           'grainy': 1,
#           'ground': 1,
#           'have': 1,
#           'heard': 1,
#           'here': 2,
#           'ill': 1,
#           'in': 1,
#           'inside': 1,
#           'is': 2,
#           'it': 3,
#           'just': 1,
#           'like': 1,
#           'long': 1,
#           'many': 1,
#           'my': 1,
#           'of': 1,
#           'ok': 1,
#           'open': 1,
#           'ordered': 1,
#           'part': 1,
#           'past': 1,
#           'place': 1,
#           'pm': 1,
#           'president': 1,
#           'say': 1,
#           'short': 1,
#           'skip': 1,
#           'story': 1,
#           'such': 1,
#           'sure': 1,
#           'taco': 1,
#           'tamale': 2,
#           'tasted': 1,
#           'that': 1,
#           'the': 4,
#           'this': 2,
#           'to': 2,
#           'walked': 1,
#           'was': 3,
#           'we': 2,
#           'went': 1,
#           'which': 1,
#           'with': 1,
#           'wont': 1,
#           'you': 1}),
#  Counter({'!': 1,
#           'ale': 1,
#           'all': 1,
#           'and': 2,
#           'are': 1,
#           'beer': 1,
#           'beers': 1,
#           'best': 1,
#           'but': 1,
#           'can': 1,
#           'comes': 1,
#           'decide': 1,
#           'devil': 1,
#           'favs': 1,
#           'four': 1,
#           'fun': 1,
#           'go': 1,
#           'good': 1,
#           'it': 1,
#           'its': 2,
#           'just': 1,
#           'like': 1,
#           'my': 1,
#           'not': 1,
#           'order': 1,
#           'out': 1,
#           'peaks': 1,
#           'sampler': 1,
#           'santan': 1,
#           'so': 2,
#           'sunspot': 1,
#           'the': 3,
#           'which': 1,
#           'with': 1,
#           'you': 2}),
#  Counter({'am': 1,
#           'and': 1,
#           'are': 1,
#           'around': 1,
#           'at': 1,
#           'beers': 1,
#           'boyfriend': 1,
#           'buzz': 1,
#           'closes': 1,
#           'early': 2,
#           'fav': 1,
#           'game': 1,
#           'get': 1,
#           'go': 1,
#           'good': 1,
#           'in': 1,
#           'is': 1,
#           'kicks': 1,
#           'kitchen': 1,
#           'midnight': 1,
#           'my': 1,
#           'nights': 1,
#           'of': 1,
#           'packed': 1,
#           'place': 1,
#           'pretty': 1,
#           'priced': 1,
#           'save': 1,
#           'seat': 1,
#           'so': 1,
#           'stein': 1,
#           'super': 1,
#           'the': 1,
#           'to': 1,
#           'too': 1,
#           'when': 1,
#           'which': 1,
#           'your': 1}),
#  Counter({'??': 1,
#           '??!': 1,
#           'about': 1,
#           'afford': 1,
#           'after': 1,
#           'all': 2,
#           'and': 4,
#           'are': 1,
#           'asada': 1,
#           'back': 1,
#           'be': 1,
#           'becuase': 1,
#           'bf': 1,
#           'burrito': 2,
#           'but': 4,
#           'by': 1,
#           'called': 1,
#           'can': 1,
#           'carne': 1,
#           'carry': 1,
#           'cars': 1,
#           'chile': 2,
#           'concerned': 1,
#           'could': 1,
#           'cups': 1,
#           'daytime': 1,
#           'definite': 1,
#           'dive': 1,
#           'dont': 2,
#           'expensive': 1,
#           'filibertos': 1,
#           'flautas': 1,
#           'food': 2,
#           'for': 3,
#           'gauc': 1,
#           'good': 4,
#           'green': 1,
#           'had': 1,
#           'has': 1,
#           'have': 2,
#           'how': 1,
#           'if': 1,
#           'im': 2,
#           'in': 3,
#           'is': 4,
#           'it': 5,
#           'items': 1,
#           'life': 1,
#           'like': 3,
#           'long': 1,
#           'lot': 1,
#           'lots': 1,
#           'made': 1,
#           'maybe': 1,
#           'me': 1,
#           'meat': 1,
#           'meats': 1,
#           'menu': 3,
#           'mexican': 1,
#           'minutes': 1,
#           'my': 3,
#           'not': 1,
#           'of': 6,
#           'okay': 1,
#           'on': 2,
#           'only': 1,
#           'or': 1,
#           'ordered': 1,
#           'orders': 1,
#           'our': 2,
#           'over': 1,
#           'parking': 1,
#           'part': 1,
#           'people': 1,
#           'purse': 1,
#           'rave': 1,
#           'red': 1,
#           'restaurant': 1,
#           'rolled': 1,
#           'salsa': 2,
#           'serve': 1,
#           'simple': 1,
#           'size': 1,
#           'sketchy': 1,
#           'so': 3,
#           'something': 1,
#           'sorry': 1,
#           'stud': 1,
#           'table': 1,
#           'taco': 1,
#           'taquitos': 1,
#           'that': 2,
#           'the': 15,
#           'then': 1,
#           'there': 2,
#           'they': 3,
#           'thimble': 1,
#           'thimbles': 1,
#           'thinking': 1,
#           'ticket': 1,
#           'time': 1,
#           'to': 6,
#           'tons': 1,
#           'too': 2,
#           'took': 1,
#           'town': 1,
#           'tray': 1,
#           'truck': 1,
#           'use': 1,
#           'was': 7,
#           'way': 1,
#           'we': 1,
#           'weird': 1,
#           'when': 1,
#           'with': 1,
#           'would': 1}),
#  Counter({'all': 1,
#           'and': 4,
#           'are': 1,
#           'at': 1,
#           'better': 1,
#           'breakfast': 1,
#           'burrito': 1,
#           'burritos': 1,
#           'but': 1,
#           'california': 1,
#           'casual': 1,
#           'counter': 1,
#           'crave': 2,
#           'down': 1,
#           'edible': 1,
#           'go': 1,
#           'good': 3,
#           'hardly': 1,
#           'if': 1,
#           'inside': 1,
#           'is': 4,
#           'it': 2,
#           'main': 1,
#           'meh': 1,
#           'never': 1,
#           'no': 1,
#           'or': 1,
#           'order': 1,
#           'place': 3,
#           'reason': 1,
#           'request': 1,
#           'salsa': 1,
#           'someone': 1,
#           'that': 1,
#           'the': 3,
#           'their': 2,
#           'there': 2,
#           'this': 2,
#           'though': 2,
#           'to': 1,
#           'turn': 1,
#           'wanted': 1,
#           'would': 1,
#           'you': 1}),
#  Counter({'!': 2,
#           'accessible': 1,
#           'advantage': 1,
#           'all': 2,
#           'also': 2,
#           'ambiance': 1,
#           'and': 4,
#           'calamari': 1,
#           'chicken': 1,
#           'delicious': 1,
#           'dim': 1,
#           'duck': 1,
#           'enjoying': 1,
#           'for': 1,
#           'great': 3,
#           'greek': 1,
#           'had': 2,
#           'halibut': 1,
#           'has': 1,
#           'is': 1,
#           'it': 2,
#           'italian': 1,
#           'lamb': 1,
#           'lightrail': 1,
#           'meatballs': 1,
#           'nice': 1,
#           'northern': 1,
#           'of': 2,
#           'options': 1,
#           'pasta': 1,
#           'patio': 1,
#           'personalities': 1,
#           'place': 1,
#           'public': 1,
#           'salmon': 1,
#           'servers': 1,
#           'service': 1,
#           'shrimp': 1,
#           'some': 1,
#           'take': 1,
#           'that': 1,
#           'the': 4,
#           'this': 1,
#           'those': 1,
#           'time': 1,
#           'transportation': 1,
#           'upscale': 1,
#           'veal': 1,
#           'very': 1,
#           'via': 1,
#           'was': 2,
#           'with': 1,
#           'you': 1}),
#  Counter({'!': 1,
#           'again': 1,
#           'ai': 1,
#           'an': 1,
#           'and': 3,
#           'as': 1,
#           'ask': 1,
#           'bar': 1,
#           'beans': 1,
#           'bill': 1,
#           'broke': 1,
#           'busy': 1,
#           'by': 1,
#           'can': 1,
#           'class': 1,
#           'crab': 1,
#           'daily': 1,
#           'do': 1,
#           'else': 1,
#           'extra': 1,
#           'first': 1,
#           'flown': 1,
#           'for': 1,
#           'fund': 1,
#           'great': 1,
#           'green': 1,
#           'grouper': 2,
#           'had': 2,
#           'helped': 1,
#           'if': 1,
#           'in': 2,
#           'is': 2,
#           'it': 2,
#           'live': 1,
#           'lobster': 1,
#           'mashed': 1,
#           'music': 1,
#           'night': 1,
#           'on': 1,
#           'or': 1,
#           'order': 1,
#           'ordered': 2,
#           'our': 1,
#           'place': 1,
#           'seafood': 1,
#           'seat': 1,
#           'servers': 1,
#           'something': 1,
#           'squeeze': 1,
#           'the': 5,
#           'think': 1,
#           'this': 2,
#           'to': 1,
#           'top': 1,
#           'trying': 1,
#           'two': 1,
#           'way': 1,
#           'were': 1,
#           'with': 1,
#           'you': 1}),
#  Counter({'!!!': 1,
#           '!!!!!!!!!': 1,
#           'and': 2,
#           'are': 1,
#           'chicken': 2,
#           'cilantro': 1,
#           'could': 1,
#           'day': 1,
#           'dish': 1,
#           'eat': 1,
#           'every': 1,
#           'expensive': 1,
#           'favorite': 1,
#           'great': 1,
#           'greek': 1,
#           'happy': 1,
#           'here': 1,
#           'hour': 1,
#           'hummus': 1,
#           'if': 1,
#           'is': 1,
#           'jalapeo': 1,
#           'jungle': 2,
#           'love': 3,
#           'mahi': 2,
#           'menu': 1,
#           'my': 1,
#           'order': 1,
#           'pita': 2,
#           'salad': 1,
#           'shwarma': 1,
#           'some': 1,
#           'the': 4,
#           'things': 1,
#           'to': 1,
#           'with': 1,
#           'would': 1}),
#  Counter({'and': 1,
#           'beer': 1,
#           'before': 1,
#           'cool': 1,
#           'even': 1,
#           'for': 1,
#           'from': 1,
#           'good': 3,
#           'here': 1,
#           'interesting': 1,
#           'it': 2,
#           'its': 1,
#           'knew': 1,
#           'liked': 1,
#           'lunch': 1,
#           'never': 1,
#           'of': 1,
#           'out': 1,
#           'pasty': 1,
#           'pews': 1,
#           'place': 1,
#           'someone': 1,
#           'spot': 1,
#           'tables': 1,
#           'take': 1,
#           'to': 1,
#           'town': 1,
#           'was': 2,
#           'went': 1,
#           'what': 1}),
#  Counter({'!': 2,
#           'aesthetically': 1,
#           'almost': 1,
#           'an': 1,
#           'and': 17,
#           'app': 1,
#           'are': 3,
#           'as': 1,
#           'at': 2,
#           'attached': 1,
#           'back': 1,
#           'bar': 1,
#           'being': 1,
#           'bestie': 1,
#           'better': 1,
#           'bill': 1,
#           'birthday': 1,
#           'blended': 1,
#           'both': 1,
#           'breast': 1,
#           'but': 1,
#           'can': 1,
#           'carte': 1,
#           'casual': 1,
#           'cauliflower': 2,
#           'ceilings': 1,
#           'celebration': 1,
#           'checked': 1,
#           'chicken': 2,
#           'chose': 1,
#           'cocktail': 1,
#           'coming': 1,
#           'cooked': 1,
#           'cooks': 1,
#           'cool': 1,
#           'couches': 1,
#           'coulda': 1,
#           'decent': 1,
#           'dining': 1,
#           'done': 1,
#           'drink': 1,
#           'enjoyed': 1,
#           'entered': 1,
#           'entrance': 1,
#           'eyepleasing': 1,
#           'finding': 1,
#           'first': 1,
#           'fish': 2,
#           'for': 2,
#           'go': 2,
#           'good': 4,
#           'got': 1,
#           'great': 2,
#           'grits': 1,
#           'had': 4,
#           'hang': 1,
#           'have': 1,
#           'here': 2,
#           'high': 1,
#           'hip': 1,
#           'horseradish': 1,
#           'how': 1,
#           'huge': 1,
#           'if': 2,
#           'ingredients': 1,
#           'inside': 1,
#           'is': 2,
#           'it': 6,
#           'juicy': 1,
#           'just': 2,
#           'kept': 1,
#           'kitchen': 1,
#           'knowledgeable': 1,
#           'la': 1,
#           'large': 1,
#           'least': 1,
#           'left': 1,
#           'lemon': 1,
#           'like': 1,
#           'look': 1,
#           'looked': 1,
#           'looking': 1,
#           'looks': 1,
#           'love': 2,
#           'mahi': 1,
#           'mal': 1,
#           'mallory': 1,
#           'mashed': 2,
#           'meal': 2,
#           'meh': 1,
#           'menu': 1,
#           'miniwing': 1,
#           'much': 1,
#           'my': 1,
#           'of': 3,
#           'on': 4,
#           'open': 1,
#           'or': 2,
#           'ordered': 3,
#           'other': 2,
#           'our': 2,
#           'out': 1,
#           'people': 1,
#           'piece': 3,
#           'place': 2,
#           'potatoes': 3,
#           'pretty': 1,
#           'really': 1,
#           'refilled': 1,
#           'restaurant': 1,
#           'room': 1,
#           'said': 1,
#           'sauce': 1,
#           'seasoned': 1,
#           'see': 1,
#           'server': 1,
#           'service': 1,
#           'she': 1,
#           'shrimp': 1,
#           'shrimps': 1,
#           'side': 1,
#           'sides': 1,
#           'so': 5,
#           'some': 1,
#           'soup': 1,
#           'special': 1,
#           'spices': 1,
#           'spot': 2,
#           'staged': 1,
#           'started': 1,
#           'strong': 1,
#           'table': 1,
#           'the': 23,
#           'there': 3,
#           'thigh': 1,
#           'this': 2,
#           'those': 1,
#           'throughout': 1,
#           'to': 4,
#           'top': 1,
#           'totally': 2,
#           'trendy': 2,
#           'trouble': 1,
#           'try': 1,
#           'two': 1,
#           'up': 1,
#           'us': 1,
#           'very': 6,
#           'warehouse': 1,
#           'was': 14,
#           'waters': 1,
#           'we': 3,
#           'well': 2,
#           'went': 1,
#           'were': 1,
#           'with': 4,
#           'without': 1,
#           'you': 2,
#           'your': 2}),
#  Counter({'attitude': 1,
#           'completely': 1,
#           'fire': 1,
#           'historic': 1,
#           'honestly': 1,
#           'if': 1,
#           'ignored': 1,
#           'it': 1,
#           'me': 1,
#           'mixed': 1,
#           'needed': 1,
#           'of': 1,
#           'off': 1,
#           'on': 2,
#           'orders': 1,
#           'our': 1,
#           'party': 1,
#           'restaurant': 1,
#           'rude': 1,
#           'spit': 1,
#           'staff': 2,
#           'that': 2,
#           'the': 2,
#           'this': 1,
#           'to': 1,
#           'turned': 1,
#           'up': 1,
#           'us': 1,
#           'was': 1,
#           'waters': 1,
#           'we': 1,
#           'were': 1,
#           'when': 1,
#           'would': 1,
#           'you': 2}),
#  Counter({'american': 1,
#           'an': 1,
#           'and': 2,
#           'are': 1,
#           'at': 2,
#           'barrios': 1,
#           'beans': 1,
#           'beautiful': 1,
#           'best': 1,
#           'bf': 1,
#           'cafe': 1,
#           'chips': 1,
#           'could': 1,
#           'doing': 1,
#           'first': 3,
#           'for': 1,
#           'fries': 1,
#           'guacamole': 1,
#           'he': 1,
#           'home': 1,
#           'hot': 1,
#           'in': 2,
#           'insisted': 1,
#           'is': 1,
#           'italian': 1,
#           'loaf': 1,
#           'look': 1,
#           'looking': 1,
#           'lunch': 1,
#           'made': 1,
#           'mexican': 1,
#           'more': 1,
#           'my': 1,
#           'no': 3,
#           'not': 1,
#           'of': 2,
#           'ok': 1,
#           'on': 1,
#           'phoenix': 1,
#           'place': 1,
#           'restaurant': 1,
#           'review': 1,
#           'sauces': 1,
#           'served': 1,
#           'so': 1,
#           'sorry': 1,
#           'stead': 1,
#           'tacos': 1,
#           'the': 2,
#           'thing': 1,
#           'this': 1,
#           'time': 1,
#           'took': 1,
#           'tortilla': 1,
#           'tortillas': 1,
#           'traditional': 2,
#           'very': 1,
#           'was': 1,
#           'which': 1,
#           'with': 1,
#           'you': 1}),
#  Counter({'?': 1,
#           '??': 1,
#           'accommodated': 1,
#           'again': 2,
#           'and': 5,
#           'anything': 1,
#           'artichoke': 1,
#           'as': 1,
#           'being': 1,
#           'but': 1,
#           'cooler': 1,
#           'decor': 1,
#           'definitely': 1,
#           'delicious': 1,
#           'digging': 1,
#           'dip': 1,
#           'dish': 1,
#           'felt': 1,
#           'friendly': 1,
#           'from': 1,
#           'girls': 1,
#           'got': 1,
#           'great': 2,
#           'had': 1,
#           'huge': 1,
#           'if': 1,
#           'is': 1,
#           'it': 1,
#           'just': 2,
#           'large': 1,
#           'like': 1,
#           'little': 1,
#           'look': 1,
#           'lot': 1,
#           'love': 1,
#           'macaroni': 1,
#           'mention': 1,
#           'menu': 1,
#           'modern': 1,
#           'must': 1,
#           'of': 4,
#           'on': 1,
#           'or': 1,
#           'ordered': 2,
#           'our': 1,
#           'party': 1,
#           'people': 1,
#           'possible': 1,
#           'random': 1,
#           'right': 1,
#           'set': 1,
#           'so': 2,
#           'sort': 1,
#           'staff': 1,
#           'the': 7,
#           'there': 1,
#           'time': 1,
#           'trendy': 1,
#           'up': 1,
#           'uptown': 1,
#           'very': 3,
#           'vig': 1,
#           'visit': 1,
#           'was': 3,
#           'were': 1,
#           'which': 1,
#           'why': 1,
#           'would': 1}),
#  Counter({'!': 1,
#           '!!': 1,
#           '!!!!!!!!!!!!': 1,
#           'able': 1,
#           'alone': 1,
#           'an': 1,
#           'and': 8,
#           'as': 1,
#           'back': 1,
#           'be': 1,
#           'because': 1,
#           'bomb': 1,
#           'but': 2,
#           'by': 1,
#           'cartel': 2,
#           'close': 1,
#           'coffee': 4,
#           'do': 1,
#           'eat': 1,
#           'extra': 1,
#           'filled': 1,
#           'food': 1,
#           'go': 1,
#           'good': 1,
#           'great': 1,
#           'half': 1,
#           'ham': 1,
#           'have': 1,
#           'hipster': 1,
#           'house': 1,
#           'ill': 1,
#           'is': 5,
#           'it': 2,
#           'its': 1,
#           'just': 1,
#           'like': 1,
#           'love': 1,
#           'me': 1,
#           'mentioned': 1,
#           'money': 1,
#           'morning': 1,
#           'my': 1,
#           'need': 1,
#           'of': 1,
#           'omg': 1,
#           'only': 1,
#           'order': 1,
#           'ordered': 1,
#           'our': 2,
#           'patient': 1,
#           'place': 2,
#           'really': 1,
#           'right': 1,
#           'sandwich': 2,
#           'scene': 1,
#           'server': 1,
#           'servers': 1,
#           'service': 1,
#           'sides': 1,
#           'slow': 1,
#           'so': 1,
#           'sort': 1,
#           'still': 1,
#           'stoked': 1,
#           'that': 1,
#           'the': 7,
#           'there': 1,
#           'this': 2,
#           'to': 4,
#           'torta': 1,
#           'up': 1,
#           'was': 2,
#           'way': 1,
#           'well': 1,
#           'went': 1,
#           'why': 1,
#           'work': 1,
#           'you': 1}),
#  Counter({'!': 3,
#           '!!!': 1,
#           'after': 1,
#           'all': 1,
#           'an': 1,
#           'and': 8,
#           'appetizer': 2,
#           'artichoke': 1,
#           'asian': 1,
#           'available': 1,
#           'awesome': 1,
#           'background': 1,
#           'be': 1,
#           'bread': 1,
#           'buds': 1,
#           'but': 1,
#           'changing': 1,
#           'crab': 1,
#           'cut': 3,
#           'delicious': 1,
#           'did': 1,
#           'dining': 2,
#           'dip': 1,
#           'dungess': 1,
#           'experience': 1,
#           'explained': 1,
#           'filet': 2,
#           'filled': 1,
#           'finish': 1,
#           'flavor': 1,
#           'flavors': 1,
#           'flow': 1,
#           'give': 1,
#           'glad': 1,
#           'got': 1,
#           'great': 3,
#           'grits': 1,
#           'had': 1,
#           'help': 1,
#           'his': 1,
#           'in': 2,
#           'includes': 1,
#           'into': 1,
#           'it': 6,
#           'juices': 1,
#           'just': 1,
#           'knowlegable': 1,
#           'large': 1,
#           'leak': 1,
#           'low': 1,
#           'makes': 1,
#           'me': 2,
#           'mediumwell': 1,
#           'menu': 2,
#           'mignon': 1,
#           'mistake': 1,
#           'music': 1,
#           'my': 4,
#           'no': 1,
#           'of': 1,
#           'ordered': 1,
#           'our': 1,
#           'out': 1,
#           'oz': 1,
#           'paired': 1,
#           'patio': 1,
#           'playing': 1,
#           'prime': 1,
#           'quiet': 1,
#           'regretted': 1,
#           'remembering': 1,
#           'rib': 1,
#           'rice': 1,
#           'room': 1,
#           'seasonally': 1,
#           'seating': 1,
#           'second': 1,
#           'seeing': 1,
#           'server': 1,
#           'service': 1,
#           'shrimp': 1,
#           'sitting': 1,
#           'so': 1,
#           'some': 1,
#           'sort': 1,
#           'steak': 1,
#           'taste': 1,
#           'that': 3,
#           'the': 5,
#           'think': 1,
#           'third': 1,
#           'to': 3,
#           'travis': 2,
#           'trio': 3,
#           'up': 2,
#           'view': 1,
#           'was': 7,
#           'we': 2,
#           'with': 4,
#           'would': 1}),
#  Counter({'!': 1,
#           '!!': 1,
#           'after': 1,
#           'all': 1,
#           'almost': 1,
#           'and': 5,
#           'bad': 1,
#           'bar': 1,
#           'because': 1,
#           'been': 1,
#           'beginning': 1,
#           'bigger': 1,
#           'boy': 1,
#           'brazilian': 1,
#           'bull': 1,
#           'but': 1,
#           'by': 1,
#           'cafeteria': 1,
#           'card': 1,
#           'celebrating': 1,
#           'coma': 1,
#           'come': 1,
#           'cooked': 1,
#           'cuts': 1,
#           'day': 1,
#           'dessert': 1,
#           'did': 1,
#           'dining': 1,
#           'eat': 1,
#           'effect': 1,
#           'even': 1,
#           'experience': 1,
#           'fantastic': 1,
#           'feed': 1,
#           'felt': 1,
#           'flipped': 1,
#           'food': 1,
#           'full': 2,
#           'get': 2,
#           'getting': 1,
#           'got': 1,
#           'green': 1,
#           'grossed': 1,
#           'had': 4,
#           'holiday': 1,
#           'horrible': 1,
#           'in': 2,
#           'is': 1,
#           'it': 4,
#           'last': 1,
#           'left': 2,
#           'like': 1,
#           'linens': 1,
#           'many': 1,
#           'masses': 1,
#           'me': 1,
#           'meat': 1,
#           'meats': 2,
#           'night': 1,
#           'of': 3,
#           'on': 1,
#           'organized': 1,
#           'our': 2,
#           'out': 1,
#           'packed': 1,
#           'past': 2,
#           'people': 1,
#           'placed': 1,
#           'ready': 1,
#           'room': 1,
#           'salad': 1,
#           'sat': 1,
#           'servers': 1,
#           'so': 3,
#           'squeezing': 1,
#           'still': 1,
#           'sure': 1,
#           'table': 1,
#           'tasty': 1,
#           'than': 1,
#           'that': 1,
#           'the': 12,
#           'there': 1,
#           'this': 2,
#           'though': 1,
#           'through': 1,
#           'tight': 2,
#           'to': 4,
#           'too': 1,
#           'took': 1,
#           'trade': 1,
#           'travis': 1,
#           'us': 1,
#           'valentine': 1,
#           'very': 3,
#           'wards': 1,
#           'was': 7,
#           'we': 6,
#           'weekend': 1,
#           'went': 1,
#           'were': 3,
#           'when': 1,
#           'which': 1,
#           'while': 1,
#           'would': 1,
#           'yummy': 1}),
#  Counter({'!!!': 1,
#           'afternoon': 1,
#           'aka': 1,
#           'along': 1,
#           'amazing': 2,
#           'and': 4,
#           'az': 1,
#           'beans': 1,
#           'beautiful': 1,
#           'bring': 1,
#           'but': 1,
#           'chicken': 1,
#           'chili': 2,
#           'cuts': 1,
#           'damn': 1,
#           'dog': 2,
#           'drumlets': 1,
#           'during': 1,
#           'etc': 1,
#           'for': 2,
#           'fresh': 2,
#           'good': 1,
#           'great': 2,
#           'green': 1,
#           'had': 1,
#           'happy': 1,
#           'have': 1,
#           'hearty': 1,
#           'here': 1,
#           'hour': 1,
#           'if': 1,
#           'it': 4,
#           'just': 3,
#           'liked': 1,
#           'lunch': 2,
#           'made': 1,
#           'me': 2,
# ...
#           'any': 1,
#           'appetizers': 1,
#           'armitage': 1,
#           'arrived': 1,
#           'artichoke': 2,
#           'as': 3,
#           'asiago': 1,
#           'at': 4,
#           'ate': 1,
#           'bar': 2,
#           'barely': 1,
#           'bars': 2,
#           'basil': 1,
#           'bbqesque': 1,
#           'be': 1,
#           'big': 1,
#           'bistro': 1,
#           'bomberos': 2,
#           'bread': 4,
#           'bruschetta': 9,
#           'bummer': 1,
#           'but': 5,
#           'cheddar': 2,
#           'cheese': 3,
#           'choose': 1,
#           'chopped': 2,
#           'come': 1,
#           'contributed': 1,
#           'could': 1,
#           'cut': 1,
#           'decent': 1,
#           'definitely': 3,
#           'delicious': 1,
#           'described': 1,
#           'did': 6,
#           'different': 2,
#           'dig': 1,
#           'dip': 4,
#           'dipping': 2,
#           'disappointing': 1,
#           'discounted': 1,
#           'dish': 1,
#           'dressed': 1,
#           'due': 1,
#           'effort': 1,
#           'either': 1,
#           'elsewhere': 1,
#           'enjoy': 2,
#           'entirely': 1,
#           'especially': 1,
#           'essentially': 1,
#           'even': 1,
#           'experience': 1,
#           'fact': 1,
#           'familiar': 1,
#           'favorite': 2,
#           'feel': 2,
#           'few': 1,
#           'first': 2,
#           'flavor': 1,
#           'for': 4,
#           'french': 3,
#           'frequent': 1,
#           'fresh': 4,
#           'fries': 3,
#           'garlic': 4,
#           'get': 1,
#           'glasses': 1,
#           'globby': 1,
#           'good': 4,
#           'gorgonzola': 2,
#           'got': 2,
#           'had': 1,
#           'half': 1,
#           'halforder': 1,
#           'happy': 3,
#           'hearts': 1,
#           'here': 1,
#           'hh': 1,
#           'high': 1,
#           'highly': 1,
#           'hopes': 1,
#           'hour': 3,
#           'if': 1,
#           'impression': 1,
#           'impressive': 2,
#           'improvement': 1,
#           'in': 3,
#           'into': 3,
#           'irish': 2,
#           'is': 6,
#           'it': 9,
#           'lastly': 1,
#           'lasts': 1,
#           'later': 1,
#           'let': 1,
#           'like': 1,
#           'love': 1,
#           'marinara': 1,
#           'menu': 1,
#           'money': 1,
#           'most': 2,
#           'mozzarella': 4,
#           'much': 3,
#           'mushroom': 2,
#           'my': 2,
#           'next': 3,
#           'normal': 1,
#           'normalsized': 1,
#           'not': 3,
#           'of': 9,
#           'okay': 1,
#           'on': 4,
#           'one': 3,
#           'order': 1,
#           'ordered': 1,
#           'other': 5,
#           'our': 3,
#           'out': 1,
#           'overall': 1,
#           'overly': 2,
#           'piece': 1,
#           'pieces': 1,
#           'pita': 1,
#           'plus': 1,
#           'pm': 1,
#           'portion': 1,
#           'portions': 1,
#           'postino': 1,
#           'prefer': 2,
#           'pretty': 1,
#           'price': 3,
#           'pricing': 1,
#           'provided': 1,
#           'ranch': 1,
#           'ravioli': 2,
#           'really': 4,
#           'receiving': 1,
#           'red': 1,
#           'redpepper': 1,
#           'roasted': 2,
#           'sampled': 2,
#           'sauce': 3,
#           'sauces': 1,
#           'seasoned': 1,
#           'seeing': 1,
#           'seem': 1,
#           'served': 1,
#           'shabby': 1,
#           'since': 1,
#           'sliced': 1,
#           'slices': 1,
#           'smaller': 1,
#           'so': 2,
#           'some': 3,
#           'special': 1,
#           'spinach': 4,
#           'spots': 1,
#           'start': 1,
#           'sticky': 1,
#           'taste': 1,
#           'th': 1,
#           'than': 2,
#           'that': 4,
#           'the': 26,
#           'their': 1,
#           'them': 1,
#           'there': 2,
#           'these': 1,
#           'they': 2,
#           'thin': 1,
#           'this': 4,
#           'though': 1,
#           'til': 1,
#           'time': 1,
#           'to': 6,
#           'toasted': 2,
#           'tomato': 4,
#           'tomatoes': 2,
#           'too': 1,
#           'toppings': 1,
#           'twist': 1,
#           'type': 4,
#           'types': 2,
#           'unimpressive': 1,
#           'up': 4,
#           'us': 1,
#           'use': 1,
#           'used': 1,
#           'usually': 1,
#           'valley': 1,
#           'variety': 1,
#           'very': 1,
#           'visited': 1,
#           'warm': 3,
#           'was': 14,
#           'we': 11,
#           'went': 1,
#           'were': 4,
#           'which': 4,
#           'wine': 7,
#           'with': 10,
#           'worth': 1,
#           'yesterday': 1,
#           'you': 3}),
#  Counter({'about': 1,
#           'after': 2,
#           'ale': 1,
#           'ales': 1,
#           'all': 4,
#           'also': 2,
#           'an': 1,
#           'and': 3,
#           'aok': 2,
#           'are': 2,
#           'around': 1,
#           'as': 2,
#           'at': 2,
#           'awesome': 1,
#           'back': 1,
#           'bar': 1,
#           'basically': 1,
#           'be': 1,
#           'been': 2,
#           'beer': 2,
#           'being': 1,
#           'better': 1,
#           'bill': 1,
#           'bit': 1,
#           'bottles': 1,
#           'brews': 1,
#           'burger': 1,
#           'busy': 1,
#           'but': 1,
#           'ca': 1,
#           'can': 1,
#           'candied': 1,
#           'carry': 1,
#           'cheese': 2,
#           'choices': 1,
#           'choose': 1,
#           'crumbles': 1,
#           'currently': 1,
#           'day': 2,
#           'decent': 2,
#           'delicious': 1,
#           'did': 1,
#           'disappeared': 1,
#           'do': 1,
#           'dressing': 1,
#           'else': 1,
#           'enjoyed': 2,
#           'entree': 1,
#           'every': 1,
#           'exactly': 1,
#           'except': 1,
#           'fine': 1,
#           'food': 1,
#           'for': 5,
#           'from': 1,
#           'good': 2,
#           'gorgonzola': 2,
#           'greens': 1,
#           'grilled': 1,
#           'had': 2,
#           'half': 2,
#           'happy': 2,
#           'has': 1,
#           'have': 4,
#           'helping': 1,
#           'her': 2,
#           'highly': 1,
#           'hood': 1,
#           'hope': 1,
#           'hour': 1,
#           'imagine': 1,
#           'in': 2,
#           'incident': 1,
#           'including': 1,
#           'initial': 1,
#           'is': 5,
#           'isolated': 1,
#           'it': 4,
#           'item': 1,
#           'just': 5,
#           'lackluster': 1,
#           'least': 1,
#           'like': 2,
#           'limited': 1,
#           'long': 2,
#           'luckily': 1,
#           'make': 1,
#           'makes': 1,
#           'may': 1,
#           'maybe': 1,
#           'menu': 1,
#           'minutes': 1,
#           'mirror': 2,
#           'mixed': 1,
#           'moon': 1,
#           'more': 1,
#           'mozzarella': 2,
#           'my': 3,
#           'next': 1,
#           'normally': 1,
#           'not': 2,
#           'occasion': 2,
#           'of': 6,
#           'oil': 1,
#           'on': 4,
#           'opted': 1,
#           'or': 2,
#           'other': 3,
#           'our': 3,
#           'out': 2,
#           'pale': 2,
#           'past': 1,
#           'pasta': 1,
#           'pay': 1,
#           'paying': 1,
#           'pear': 3,
#           'pecans': 1,
#           'people': 1,
#           'periods': 1,
#           'place': 1,
#           'pond': 2,
#           'porter': 1,
#           'pretty': 3,
#           'previous': 1,
#           'price': 2,
#           'primavera': 1,
#           'problem': 1,
#           'rating': 1,
#           'ready': 1,
#           'really': 1,
#           'report': 1,
#           'salad': 4,
#           'seated': 1,
#           'see': 2,
#           'service': 3,
#           'she': 1,
#           'since': 1,
#           'slices': 1,
#           'so': 3,
#           'some': 2,
#           'something': 1,
#           'special': 1,
#           'specials': 1,
#           'sports': 1,
#           'star': 1,
#           'sticks': 2,
#           'stock': 2,
#           'suggests': 1,
#           'sure': 1,
#           'sweet': 1,
#           'talking': 1,
#           'that': 5,
#           'the': 11,
#           'their': 3,
#           'them': 1,
#           'there': 2,
#           'they': 7,
#           'this': 3,
#           'though': 2,
#           'time': 6,
#           'to': 4,
#           'today': 1,
#           'took': 1,
#           'topped': 1,
#           'touted': 1,
#           'vegfriendly': 1,
#           'veggie': 2,
#           'very': 1,
#           'vinagrette': 1,
#           'visit': 1,
#           'waitress': 1,
#           'wanted': 1,
#           'was': 5,
#           'we': 4,
#           'well': 1,
#           'were': 4,
#           'what': 3,
#           'when': 1,
#           'which': 5,
#           'wish': 1,
#           'with': 2,
#           'worth': 1}),
#  Counter({'!!!': 1,
#           'banana': 1,
#           'booyahh': 1,
#           'cupcake': 1,
#           'great': 1,
#           'vegan': 1}),
#  Counter({'!': 1,
#           'and': 3,
#           'any': 1,
#           'area': 1,
#           'bread': 3,
#           'but': 1,
#           'citrus': 1,
#           'cool': 2,
#           'day': 1,
#           'dishes': 1,
#           'diverse': 1,
#           'do': 1,
#           'dressing': 1,
#           'drizzled': 1,
#           'filled': 1,
#           'food': 1,
#           'for': 1,
#           'grain': 1,
#           'grains': 1,
#           'have': 1,
#           'in': 1,
#           'informed': 1,
#           'it': 1,
#           'loaded': 1,
#           'lunch': 1,
#           'me': 1,
#           'menu': 1,
#           'more': 1,
#           'nd': 1,
#           'of': 3,
#           'offering': 1,
#           'one': 1,
#           'open': 1,
#           'options': 1,
#           'other': 1,
#           'our': 1,
#           'outdoor': 1,
#           'patio': 1,
#           'pita': 1,
#           'please': 1,
#           'popped': 1,
#           'salad': 1,
#           'some': 1,
#           'start': 1,
#           'tasty': 1,
#           'that': 1,
#           'the': 3,
#           'they': 2,
#           'to': 1,
#           'ton': 1,
#           'tons': 1,
#           'totally': 1,
#           'tried': 1,
#           'try': 1,
#           'up': 1,
#           'us': 1,
#           'vegan': 3,
#           'veggies': 1,
#           'very': 1,
#           'vibe': 1,
#           'vinaigrette': 1,
#           'visit': 1,
#           'waitress': 1,
#           'wanted': 1,
#           'was': 2,
#           'we': 1,
#           'were': 1,
#           'whatsoever': 1,
#           'which': 1,
#           'windsor': 1,
#           'with': 3}),
#  Counter({'all': 1,
#           'also': 2,
#           'and': 3,
#           'android': 1,
#           'are': 1,
#           'area': 1,
#           'awesome': 1,
#           'be': 1,
#           'bit': 1,
#           'bruschetta': 1,
#           'but': 1,
#           'chardonnay': 1,
#           'cherry': 1,
#           'chewy': 1,
#           'could': 1,
#           'day': 1,
#           'did': 1,
#           'door': 1,
#           'even': 1,
#           'every': 1,
#           'few': 1,
#           'for': 1,
#           'francis': 1,
#           'fresh': 2,
#           'glasses': 3,
#           'gone': 1,
#           'good': 1,
#           'got': 1,
#           'great': 1,
#           'had': 2,
#           'in': 1,
#           'instead': 1,
#           'just': 1,
#           'like': 2,
#           'mentioned': 1,
#           'mistersprayed': 1,
#           'more': 1,
#           'mozz': 1,
#           'mozzarella': 1,
#           'mushy': 1,
#           'neighborhood': 1,
#           'next': 1,
#           'now': 1,
#           'of': 4,
#           'on': 3,
#           'our': 1,
#           'patio': 1,
#           'pm': 1,
#           'preferred': 1,
#           'pretty': 1,
#           'runny': 1,
#           'shaded': 1,
#           'single': 1,
#           'slices': 1,
#           'small': 1,
#           'so': 1,
#           'solid': 1,
#           'special': 1,
#           'spot': 1,
#           'spotted': 1,
#           'st': 1,
#           'still': 1,
#           'stopped': 1,
#           'sunday': 1,
#           'tasty': 1,
#           'tera': 1,
#           'the': 2,
#           'there': 1,
#           'they': 1,
#           'this': 1,
#           'thx': 1,
#           'til': 1,
#           'time': 1,
#           'to': 2,
#           'tomato': 1,
#           'tomatoes': 1,
#           'use': 1,
#           'was': 3,
#           'we': 2,
#           'which': 1,
#           'wine': 2,
#           'wish': 1,
#           'would': 1,
#           'yelp': 2}),
#  Counter({'also': 1,
#           'and': 1,
#           'area': 1,
#           'badass': 1,
#           'been': 1,
#           'beers': 1,
#           'choice': 1,
#           'diners': 1,
#           'drinks': 2,
#           'eat': 1,
#           'elsewhere': 1,
#           'entertainment': 2,
#           'environment': 1,
#           'fellow': 1,
#           'finnegan': 2,
#           'first': 1,
#           'food': 2,
#           'for': 6,
#           'gets': 1,
#           'ghetrocenter': 1,
#           'go': 1,
#           'good': 1,
#           'grab': 1,
#           'have': 2,
#           'head': 1,
#           'if': 1,
#           'impressed': 1,
#           'in': 1,
#           'irish': 1,
#           'is': 1,
#           'looking': 1,
#           'my': 2,
#           'nonvegetarians': 1,
#           'not': 1,
#           'or': 1,
#           'place': 1,
#           'probably': 1,
#           'pub': 2,
#           'so': 1,
#           'some': 1,
#           'stars': 2,
#           'summarize': 1,
#           'the': 4,
#           'then': 2,
#           'there': 1,
#           'this': 1,
#           'tim': 2,
#           'time': 1,
#           'to': 4,
#           'vegetarians': 1,
#           'with': 1,
#           'you': 2}),
#  Counter({'!': 2,
#           'and': 2,
#           'as': 1,
#           'avoid': 1,
#           'bad': 1,
#           'basil': 1,
#           'both': 1,
#           'broccoli': 1,
#           'cheese': 1,
#           'chopped': 1,
#           'combining': 1,
#           'cooked': 2,
#           'coverage': 1,
#           'cream': 1,
#           'crimini': 1,
#           'crispy': 1,
#           'crunch': 1,
#           'crust': 3,
#           'definitely': 1,
#           'delicious': 1,
#           'delish': 1,
#           'different': 1,
#           'down': 1,
#           'dressing': 1,
#           'enjoyed': 1,
#           'enough': 1,
#           'friendly': 1,
#           'from': 1,
#           'get': 1,
#           'good': 2,
#           'got': 4,
#           'great': 1,
#           'hook': 1,
#           'include': 1,
#           'ingredients': 1,
#           'is': 1,
#           'it': 1,
#           'just': 1,
#           'mushrooms': 1,
#           'my': 1,
#           'no': 1,
#           'nocheese': 1,
#           'of': 1,
#           'on': 2,
#           'orders': 1,
#           'pasta': 1,
#           'pizza': 8,
#           'really': 1,
#           'red': 3,
#           'salad': 2,
#           'sauce': 4,
#           'service': 1,
#           'she': 1,
#           'should': 1,
#           'skimpy': 2,
#           'slices': 1,
#           'someone': 1,
#           'soup': 1,
#           'staff': 1,
#           'ta': 1,
#           'tasty': 2,
#           'that': 1,
#           'the': 9,
#           'they': 2,
#           'though': 1,
#           'to': 2,
#           'tomato': 2,
#           'topping': 1,
#           'toppings': 4,
#           'up': 2,
#           'variety': 1,
#           'vegan': 1,
#           'vegans': 1,
#           'vinagrette': 1,
#           'was': 2,
#           'well': 2,
#           'were': 1,
#           'when': 1,
#           'wife': 1,
#           'with': 2,
#           'wound': 1,
#           'you': 1}),
#  Counter({'also': 1,
#           'although': 1,
#           'and': 1,
#           'bacon': 1,
#           'breakfast': 1,
#           'chicken': 1,
#           'choice': 1,
#           'enjoyed': 1,
#           'fav': 1,
#           'for': 1,
#           'fried': 1,
#           'good': 1,
#           'great': 2,
#           'had': 1,
#           'in': 1,
#           'it': 1,
#           'liked': 1,
#           'location': 1,
#           'lox': 1,
#           'mall': 1,
#           'my': 2,
#           'new': 1,
#           'now': 1,
#           'omelette': 1,
#           'our': 1,
#           'potato': 1,
#           'really': 1,
#           'scramble': 1,
#           'second': 1,
#           'st': 1,
#           'steak': 1,
#           'strip': 1,
#           'sweet': 1,
#           'table': 1,
#           'the': 2,
#           'this': 2,
#           'time': 1,
#           'totsjust': 1,
#           'visit': 1,
#           'was': 3,
#           'with': 1})]

# %%
file = open('wordvec_6B_50d.txt', encoding='UTF-8')
vec, wdvec_dict, order = [], {}, 0
for line in file:
    item = line.strip().split()
    vec.append(list(map(float,item[1:])))
    wdvec_dict[item[0]] = order
    order += 1
file.close()
def w2v(word):
    if (word in wdvec_dict):
        return np.array([1]+vec[wdvec_dict[word]])
    return np.zeros(51)

# %%
def evaluate(TP, FN, TN, FP):
	Accuracy = (TP + TN) / np.float64(TP + FP + TN + FN)
	return Accuracy
def check(res, std):
	count = [0]*4
	for r, s in zip(res, std):
		wrong = int(r != s)
		neg = int(s != 1)
		count[neg * 2 + wrong] += 1
	print(evaluate(*count))
	return 
def sigmoid(X):
	return 1 / (1 + np.exp(-X))
class LogicalRegression(object):
	"""docstring for LogicalRegression"""
	def __init__(self, train_X, train_y, weights=None, times=1000, alpha=0.01, lambda_=1, c=1, style='batch'):
		self.train_X = train_X
		self.train_y = train_y
		self.times = times
		self.alpha = alpha
		self.c = c
# 		gradient = []
		if not weights.any():
			weights = np.zeros((train_X.shape[1],M)) # M*1
		epsilon = 1e-6
		self.w0 = weights # M*1
		p = sigmoid(np.dot(train_X, self.w0)) # N*M X M*1 = N*1
		J0 = self.logistic_cost(p, train_y) + (self.w0*self.w0).sum()
		for t in range(times):
			p_y = p - train_y
			w = self.w0 - alpha * (np.dot(train_X.T, p_y) + lambda_*self.w0/2) / len(train_y)
			# print(np.dot(train_X.transpose(), p_y))
# 			gradient.append(np.sum(-np.dot(train_X.T, p_y)))
			p = sigmoid(np.dot(train_X, w))
			J = self.logistic_cost(p, train_y) + (w*w).sum()
			print('times:',t,'   J0:',J0,'   J:',J)
			if J < J0: # not convergent
				J0 = J
				self.w0 = w
			else:
				alpha /= c
# 				if np.linalg.norm(w - self.w0) < epsilon * np.linalg.norm(self.w0):
# 					# print('times: ', t)
# 					break
		return # M*1
	def LR(self, train_X, train_y,weights=None):
		gradient = []
		if weights == None:
			weights = np.zeros((1,train_X.shape[1])) # 1*M
		# alpha = 0.000001
		epsilon = 1e-3
		w0 = weights.T # M*1
		# print(w0)
		p = sigmoid(np.dot(train_X, w0)) # N*M X M*1 = N*1
		J0 = self.logistic_cost(p, train_y)
		K0 = K00 = J0
		for t in range(self.times):
			p_y = p - train_y
			w = w0 - self.alpha * np.dot(train_X.T, p_y) 
			# print(np.dot(train_X.transpose(), p_y))
			gradient.append(np.sum(-np.dot(train_X.T, p_y)))
			# w = w0 - alpha * np.dot(train_X.transpose(), p_y) / len(p) - lambda_ * w0 / len(p) #40*1
			p = sigmoid(np.dot(train_X, w))
			J = self.logistic_cost(p, train_y)
			if t > 7 and K00 == J:
				break
			K00 = K0
			K0 = J
			if J < J0: # not convergent
				J0 = J
				w0 = w
			else:
				self.alpha /= self.c
				if np.linalg.norm(w - w0) < epsilon * np.linalg.norm(w0):
					# print('times: ', t)
					break
		return w0 # M*1
	def logistic_cost(self, p, train_y):
		_p = copy.deepcopy(p)
		_p[train_y == 0] = 1 - _p[train_y == 0]
		return -sum(np.log(_p+0.000001)) 
	def predict(self, test_X):
		return  sigmoid(np.dot(test_X, self.w0))
	def groupValidation(self, k=10):
		n = self.train_X.shape[0]
		m = math.ceil(n/k)
		n_id = list(range(n))
		random.shuffle(n_id)
		L = []
		L += list(map(lambda x:n_id[x:x+m] ,map(lambda i:i*m, range(10))))
		return L
	def crossValidation(self):
		L = self.groupValidation()
		for i in range(len(L)):
			cp_L = copy.deepcopy(L)
			vali_id = cp_L.pop(i)
			vali_X, vali_y = self.train_X[vali_id], self.train_y[vali_id]
			tra_x, tra_y = self.train_X[reduce(operator.add,cp_L)], self.train_y[reduce(operator.add,cp_L)]
			weights = self.LR(tra_x, tra_y)
			res = np.dot(vali_X, weights)
			res = list(map(lambda x: 1 if x > 0 else 0, res))
			check(res, vali_y)
		return

# %%
def writefile(filename, res):
    file = open(filename,'w')
    for i in res:
        file.write(i+'\n')
    file.close()
    return
def check_label(std, res):
    return (np.array(res) == np.array(std)).sum() / len(std)
def labelTonum(label):
    L_y = list(map(lambda x:1 if x =='LOW' else 0, label))
    L_y = np.array([L_y]).T
    M_y = list(map(lambda x:1 if x =='MID' else 0, label))
    M_y = np.array([M_y]).T
    H_y = list(map(lambda x:1 if x =='HIG' else 0, label))
    H_y = np.array([H_y]).T
    return L_y, M_y, H_y
def numTolabel(y):
    name = ['LOW','MID','HIG']
    return list(map(lambda x:name[x],y))

# %%
def scaling(train_X, test_X):
    mean = train_X.mean(axis=0)
    std = train_X.std(axis=0)
    ones1 = np.ones((train_X.shape[0],1))
    ones2 = np.ones((test_X.shape[0],1))
    m1 = np.kron(ones1, mean)
    s1 = np.kron(ones1, std)
    m2 = np.kron(ones2, mean)
    s2 = np.kron(ones2, std)
    r1 = (train_X - m1) / s1
    r2 = (test_X - m2) / s2
    return r1, r2

# %%
###################################LR Validtion############################
train_x = []
for ts in new_trainset:
    v = np.array(list(map(w2v,ts.keys())))
    if not v.any():
        v = np.zeros((1,51))
    train_x.append(v.mean(axis=0))
train_x = np.array(train_x)

test_x = []
for ts in test_set:
    v = np.array(list(map(w2v,ts.keys())))
    if not v.any():
        v = np.zeros((1,51))
    test_x.append(v.mean(axis=0))
test_x = np.array(test_x)
                 
valid_x = []
for ts in valid_set:
    v = np.array(list(map(w2v,ts.keys())))
    if not v.any():
        v = np.zeros((1,51))
    valid_x.append(v.mean(axis=0))
valid_x = np.array(valid_x)

# %%
tr_x = train_x
te_x = test_x
va_x = valid_x
_,te_x = scaling(tr_x, te_x)
tr_x,va_x = scaling(tr_x, va_x)
L_y, M_y, H_y = labelTonum(new_label)
model_L0 = LogicalRegression(tr_x, L_y,times=120, alpha=0.2)
model_M0 = LogicalRegression(tr_x, M_y,times=80, alpha=0.2)
model_H0 = LogicalRegression(tr_x, H_y,times=70, alpha=0.2)
###################################LR Validtion############################
# Out:
# times: 0    J0: [ 37325.17482808]    J: [ 36174.65744553]
# times: 1    J0: [ 36174.65744553]    J: [ 35491.60809064]
# times: 2    J0: [ 35491.60809064]    J: [ 35023.37322017]
# times: 3    J0: [ 35023.37322017]    J: [ 34672.66256351]
# times: 4    J0: [ 34672.66256351]    J: [ 34396.11302912]
# times: 5    J0: [ 34396.11302912]    J: [ 34171.00881374]
# times: 6    J0: [ 34171.00881374]    J: [ 33983.77781773]
# times: 7    J0: [ 33983.77781773]    J: [ 33825.51412913]
# times: 8    J0: [ 33825.51412913]    J: [ 33689.995562]
# times: 9    J0: [ 33689.995562]    J: [ 33572.68946229]
# times: 10    J0: [ 33572.68946229]    J: [ 33470.19670987]
# times: 11    J0: [ 33470.19670987]    J: [ 33379.91277685]
# times: 12    J0: [ 33379.91277685]    J: [ 33299.80760025]
# times: 13    J0: [ 33299.80760025]    J: [ 33228.27604197]
# times: 14    J0: [ 33228.27604197]    J: [ 33164.03297588]
# times: 15    J0: [ 33164.03297588]    J: [ 33106.03790024]
# times: 16    J0: [ 33106.03790024]    J: [ 33053.43974194]
# times: 17    J0: [ 33053.43974194]    J: [ 33005.53581652]
# times: 18    J0: [ 33005.53581652]    J: [ 32961.740907]
# times: 19    J0: [ 32961.740907]    J: [ 32921.56369181]
# times: 20    J0: [ 32921.56369181]    J: [ 32884.58858353]
# times: 21    J0: [ 32884.58858353]    J: [ 32850.46159894]
# times: 22    J0: [ 32850.46159894]    J: [ 32818.87926542]
# times: 23    J0: [ 32818.87926542]    J: [ 32789.57983676]
# times: 24    J0: [ 32789.57983676]    J: [ 32762.33628171]
# times: 25    J0: [ 32762.33628171]    J: [ 32736.95064472]
# times: 26    J0: [ 32736.95064472]    J: [ 32713.24947762]
# times: 27    J0: [ 32713.24947762]    J: [ 32691.08011325]
# times: 28    J0: [ 32691.08011325]    J: [ 32670.30760587]
# times: 29    J0: [ 32670.30760587]    J: [ 32650.81220323]
# times: 30    J0: [ 32650.81220323]    J: [ 32632.48724523]
# times: 31    J0: [ 32632.48724523]    J: [ 32615.23740727]
# times: 32    J0: [ 32615.23740727]    J: [ 32598.97722348]
# times: 33    J0: [ 32598.97722348]    J: [ 32583.62983874]
# times: 34    J0: [ 32583.62983874]    J: [ 32569.12594875]
# times: 35    J0: [ 32569.12594875]    J: [ 32555.40289543]
# times: 36    J0: [ 32555.40289543]    J: [ 32542.40389127]
# times: 37    J0: [ 32542.40389127]    J: [ 32530.07735149]
# times: 38    J0: [ 32530.07735149]    J: [ 32518.37631644]
# times: 39    J0: [ 32518.37631644]    J: [ 32507.25795022]
# times: 40    J0: [ 32507.25795022]    J: [ 32496.68310372]
# times: 41    J0: [ 32496.68310372]    J: [ 32486.61593247]
# times: 42    J0: [ 32486.61593247]    J: [ 32477.02356132]
# times: 43    J0: [ 32477.02356132]    J: [ 32467.87578925]
# times: 44    J0: [ 32467.87578925]    J: [ 32459.14482869]
# times: 45    J0: [ 32459.14482869]    J: [ 32450.80507472]
# times: 46    J0: [ 32450.80507472]    J: [ 32442.83290011]
# times: 47    J0: [ 32442.83290011]    J: [ 32435.20647288]
# times: 48    J0: [ 32435.20647288]    J: [ 32427.90559353]
# times: 49    J0: [ 32427.90559353]    J: [ 32420.91154937]
# times: 50    J0: [ 32420.91154937]    J: [ 32414.2069841]
# times: 51    J0: [ 32414.2069841]    J: [ 32407.77578053]
# times: 52    J0: [ 32407.77578053]    J: [ 32401.60295515]
# times: 53    J0: [ 32401.60295515]    J: [ 32395.67456301]
# times: 54    J0: [ 32395.67456301]    J: [ 32389.97761186]
# times: 55    J0: [ 32389.97761186]    J: [ 32384.49998449]
# times: 56    J0: [ 32384.49998449]    J: [ 32379.23036833]
# times: 57    J0: [ 32379.23036833]    J: [ 32374.1581916]
# times: 58    J0: [ 32374.1581916]    J: [ 32369.27356531]
# times: 59    J0: [ 32369.27356531]    J: [ 32364.56723043]
# times: 60    J0: [ 32364.56723043]    J: [ 32360.03050981]
# times: 61    J0: [ 32360.03050981]    J: [ 32355.65526432]
# times: 62    J0: [ 32355.65526432]    J: [ 32351.43385276]
# times: 63    J0: [ 32351.43385276]    J: [ 32347.35909523]
# times: 64    J0: [ 32347.35909523]    J: [ 32343.42423958]
# times: 65    J0: [ 32343.42423958]    J: [ 32339.6229307]
# times: 66    J0: [ 32339.6229307]    J: [ 32335.94918231]
# times: 67    J0: [ 32335.94918231]    J: [ 32332.39735107]
# times: 68    J0: [ 32332.39735107]    J: [ 32328.9621128]
# times: 69    J0: [ 32328.9621128]    J: [ 32325.63844062]
# times: 70    J0: [ 32325.63844062]    J: [ 32322.42158472]
# times: 71    J0: [ 32322.42158472]    J: [ 32319.30705387]
# times: 72    J0: [ 32319.30705387]    J: [ 32316.29059822]
# times: 73    J0: [ 32316.29059822]    J: [ 32313.36819351]
# times: 74    J0: [ 32313.36819351]    J: [ 32310.53602645]
# times: 75    J0: [ 32310.53602645]    J: [ 32307.79048118]
# times: 76    J0: [ 32307.79048118]    J: [ 32305.12812679]
# times: 77    J0: [ 32305.12812679]    J: [ 32302.54570571]
# times: 78    J0: [ 32302.54570571]    J: [ 32300.04012296]
# times: 79    J0: [ 32300.04012296]    J: [ 32297.60843621]
# times: 80    J0: [ 32297.60843621]    J: [ 32295.24784651]
# times: 81    J0: [ 32295.24784651]    J: [ 32292.95568969]
# %%
model_L1 = LogicalRegression(tr_x, L_y,weights=model_L0.w0,times=300, alpha=0.07)
model_M1 = LogicalRegression(tr_x, M_y,weights=model_M0.w0,times=300, alpha=0.07)
model_H1 = LogicalRegression(tr_x, H_y,weights=model_H0.w0,times=300, alpha=0.07)
# Out:
# times: 0    J0: [ 32239.15899819]    J: [ 32238.86277359]
# times: 1    J0: [ 32238.86277359]    J: [ 32238.56889523]
# times: 2    J0: [ 32238.56889523]    J: [ 32238.27734048]
# times: 3    J0: [ 32238.27734048]    J: [ 32237.98808698]
# times: 4    J0: [ 32237.98808698]    J: [ 32237.70111262]
# times: 5    J0: [ 32237.70111262]    J: [ 32237.41639554]
# times: 6    J0: [ 32237.41639554]    J: [ 32237.13391413]
# times: 7    J0: [ 32237.13391413]    J: [ 32236.85364704]
# times: 8    J0: [ 32236.85364704]    J: [ 32236.57557314]
# times: 9    J0: [ 32236.57557314]    J: [ 32236.29967157]
# times: 10    J0: [ 32236.29967157]    J: [ 32236.02592167]
# times: 11    J0: [ 32236.02592167]    J: [ 32235.75430305]
# times: 12    J0: [ 32235.75430305]    J: [ 32235.48479552]
# times: 13    J0: [ 32235.48479552]    J: [ 32235.21737914]
# times: 14    J0: [ 32235.21737914]    J: [ 32234.95203418]
# times: 15    J0: [ 32234.95203418]    J: [ 32234.68874113]
# times: 16    J0: [ 32234.68874113]    J: [ 32234.42748071]
# times: 17    J0: [ 32234.42748071]    J: [ 32234.16823384]
# times: 18    J0: [ 32234.16823384]    J: [ 32233.91098167]
# times: 19    J0: [ 32233.91098167]    J: [ 32233.65570554]
# times: 20    J0: [ 32233.65570554]    J: [ 32233.40238701]
# times: 21    J0: [ 32233.40238701]    J: [ 32233.15100785]
# times: 22    J0: [ 32233.15100785]    J: [ 32232.90155]
# times: 23    J0: [ 32232.90155]    J: [ 32232.65399564]
# times: 24    J0: [ 32232.65399564]    J: [ 32232.40832712]
# times: 25    J0: [ 32232.40832712]    J: [ 32232.16452699]
# times: 26    J0: [ 32232.16452699]    J: [ 32231.92257799]
# times: 27    J0: [ 32231.92257799]    J: [ 32231.68246304]
# times: 28    J0: [ 32231.68246304]    J: [ 32231.44416527]
# times: 29    J0: [ 32231.44416527]    J: [ 32231.20766797]
# times: 30    J0: [ 32231.20766797]    J: [ 32230.97295462]
# times: 31    J0: [ 32230.97295462]    J: [ 32230.74000888]
# times: 32    J0: [ 32230.74000888]    J: [ 32230.50881458]
# times: 33    J0: [ 32230.50881458]    J: [ 32230.27935574]
# times: 34    J0: [ 32230.27935574]    J: [ 32230.05161653]
# times: 35    J0: [ 32230.05161653]    J: [ 32229.82558131]
# times: 36    J0: [ 32229.82558131]    J: [ 32229.6012346]
# times: 37    J0: [ 32229.6012346]    J: [ 32229.37856107]
# times: 38    J0: [ 32229.37856107]    J: [ 32229.15754559]
# times: 39    J0: [ 32229.15754559]    J: [ 32228.93817316]
# times: 40    J0: [ 32228.93817316]    J: [ 32228.72042894]
# times: 41    J0: [ 32228.72042894]    J: [ 32228.50429827]
# times: 42    J0: [ 32228.50429827]    J: [ 32228.28976662]
# times: 43    J0: [ 32228.28976662]    J: [ 32228.07681964]
# times: 44    J0: [ 32228.07681964]    J: [ 32227.86544311]
# times: 45    J0: [ 32227.86544311]    J: [ 32227.65562297]
# times: 46    J0: [ 32227.65562297]    J: [ 32227.44734529]
# times: 47    J0: [ 32227.44734529]    J: [ 32227.24059632]
# times: 48    J0: [ 32227.24059632]    J: [ 32227.03536243]
# times: 49    J0: [ 32227.03536243]    J: [ 32226.83163014]
# times: 50    J0: [ 32226.83163014]    J: [ 32226.62938609]
# times: 51    J0: [ 32226.62938609]    J: [ 32226.4286171]
# times: 52    J0: [ 32226.4286171]    J: [ 32226.2293101]
# times: 53    J0: [ 32226.2293101]    J: [ 32226.03145215]
# times: 54    J0: [ 32226.03145215]    J: [ 32225.83503046]
# times: 55    J0: [ 32225.83503046]    J: [ 32225.64003237]
# times: 56    J0: [ 32225.64003237]    J: [ 32225.44644534]
# times: 57    J0: [ 32225.44644534]    J: [ 32225.25425697]
# times: 58    J0: [ 32225.25425697]    J: [ 32225.06345498]
# times: 59    J0: [ 32225.06345498]    J: [ 32224.87402723]
# times: 60    J0: [ 32224.87402723]    J: [ 32224.68596169]
# times: 61    J0: [ 32224.68596169]    J: [ 32224.49924645]
# times: 62    J0: [ 32224.49924645]    J: [ 32224.31386974]
# times: 63    J0: [ 32224.31386974]    J: [ 32224.12981989]
# times: 64    J0: [ 32224.12981989]    J: [ 32223.94708537]
# times: 65    J0: [ 32223.94708537]    J: [ 32223.76565474]
# times: 66    J0: [ 32223.76565474]    J: [ 32223.5855167]
# times: 67    J0: [ 32223.5855167]    J: [ 32223.40666006]
# times: 68    J0: [ 32223.40666006]    J: [ 32223.22907372]
# times: 69    J0: [ 32223.22907372]    J: [ 32223.05274674]
# times: 70    J0: [ 32223.05274674]    J: [ 32222.87766824]
# times: 71    J0: [ 32222.87766824]    J: [ 32222.70382747]
# times: 72    J0: [ 32222.70382747]    J: [ 32222.5312138]
# times: 73    J0: [ 32222.5312138]    J: [ 32222.35981668]
# times: 74    J0: [ 32222.35981668]    J: [ 32222.1896257]
# times: 75    J0: [ 32222.1896257]    J: [ 32222.02063052]
# times: 76    J0: [ 32222.02063052]    J: [ 32221.85282093]
# times: 77    J0: [ 32221.85282093]    J: [ 32221.68618679]
# times: 78    J0: [ 32221.68618679]    J: [ 32221.5207181]
# times: 79    J0: [ 32221.5207181]    J: [ 32221.35640492]
# times: 80    J0: [ 32221.35640492]    J: [ 32221.19323745]
# times: 81    J0: [ 32221.19323745]    J: [ 32221.03120595]
# times: 82    J0: [ 32221.03120595]    J: [ 32220.8703008]
# times: 83    J0: [ 32220.8703008]    J: [ 32220.71051246]
# times: 84    J0: [ 32220.71051246]    J: [ 32220.55183149]
# times: 85    J0: [ 32220.55183149]    J: [ 32220.39424855]
# times: 86    J0: [ 32220.39424855]    J: [ 32220.23775438]
# times: 87    J0: [ 32220.23775438]    J: [ 32220.08233981]
# times: 88    J0: [ 32220.08233981]    J: [ 32219.92799577]
# times: 182    J0: [ 32209.24075447]    J: [ 32209.15651639]
# times: 183    J0: [ 32209.15651639]    J: [ 32209.07278201]
# times: 184    J0: [ 32209.07278201]    J: [ 32208.98954757]
# times: 185    J0: [ 32208.98954757]    J: [ 32208.90680935]
# times: 186    J0: [ 32208.90680935]    J: [ 32208.82456365]
# times: 187    J0: [ 32208.82456365]    J: [ 32208.74280683]
# times: 188    J0: [ 32208.74280683]    J: [ 32208.66153526]
# times: 189    J0: [ 32208.66153526]    J: [ 32208.58074535]
# times: 190    J0: [ 32208.58074535]    J: [ 32208.50043352]
# times: 191    J0: [ 32208.50043352]    J: [ 32208.42059625]
# times: 192    J0: [ 32208.42059625]    J: [ 32208.34123004]
# times: 193    J0: [ 32208.34123004]    J: [ 32208.26233141]
# times: 194    J0: [ 32208.26233141]    J: [ 32208.18389692]
# times: 195    J0: [ 32208.18389692]    J: [ 32208.10592315]
# times: 196    J0: [ 32208.10592315]    J: [ 32208.02840673]
# times: 197    J0: [ 32208.02840673]    J: [ 32207.95134428]
# times: 198    J0: [ 32207.95134428]    J: [ 32207.87473249]
# times: 199    J0: [ 32207.87473249]    J: [ 32207.79856806]
# times: 200    J0: [ 32207.79856806]    J: [ 32207.72284771]
# times: 201    J0: [ 32207.72284771]    J: [ 32207.64756821]
# times: 202    J0: [ 32207.64756821]    J: [ 32207.57272632]
# times: 203    J0: [ 32207.57272632]    J: [ 32207.49831887]
# times: 204    J0: [ 32207.49831887]    J: [ 32207.42434269]
# times: 205    J0: [ 32207.42434269]    J: [ 32207.35079464]
# times: 206    J0: [ 32207.35079464]    J: [ 32207.27767162]
# times: 207    J0: [ 32207.27767162]    J: [ 32207.20497054]
# times: 208    J0: [ 32207.20497054]    J: [ 32207.13268835]
# times: 209    J0: [ 32207.13268835]    J: [ 32207.060822]
# times: 210    J0: [ 32207.060822]    J: [ 32206.9893685]
# times: 211    J0: [ 32206.9893685]    J: [ 32206.91832487]
# times: 212    J0: [ 32206.91832487]    J: [ 32206.84768813]
# times: 213    J0: [ 32206.84768813]    J: [ 32206.77745538]
# times: 214    J0: [ 32206.77745538]    J: [ 32206.70762368]
# times: 215    J0: [ 32206.70762368]    J: [ 32206.63819017]
# times: 216    J0: [ 32206.63819017]    J: [ 32206.56915199]
# times: 217    J0: [ 32206.56915199]    J: [ 32206.50050629]
# times: 218    J0: [ 32206.50050629]    J: [ 32206.43225026]
# times: 219    J0: [ 32206.43225026]    J: [ 32206.36438112]
# times: 220    J0: [ 32206.36438112]    J: [ 32206.2968961]
# times: 221    J0: [ 32206.2968961]    J: [ 32206.22979245]
# times: 222    J0: [ 32206.22979245]    J: [ 32206.16306747]
# times: 223    J0: [ 32206.16306747]    J: [ 32206.09671843]
# times: 224    J0: [ 32206.09671843]    J: [ 32206.03074268]
# times: 225    J0: [ 32206.03074268]    J: [ 32205.96513756]
# times: 226    J0: [ 32205.96513756]    J: [ 32205.89990043]
# times: 227    J0: [ 32205.89990043]    J: [ 32205.83502869]
# times: 228    J0: [ 32205.83502869]    J: [ 32205.77051975]
# times: 229    J0: [ 32205.77051975]    J: [ 32205.70637103]
# times: 230    J0: [ 32205.70637103]    J: [ 32205.64258]
# times: 231    J0: [ 32205.64258]    J: [ 32205.57914412]
# times: 232    J0: [ 32205.57914412]    J: [ 32205.51606089]
# times: 233    J0: [ 32205.51606089]    J: [ 32205.45332783]
# times: 234    J0: [ 32205.45332783]    J: [ 32205.39094247]
# times: 235    J0: [ 32205.39094247]    J: [ 32205.32890236]
# times: 236    J0: [ 32205.32890236]    J: [ 32205.26720509]
# times: 237    J0: [ 32205.26720509]    J: [ 32205.20584824]
# times: 238    J0: [ 32205.20584824]    J: [ 32205.14482943]
# times: 239    J0: [ 32205.14482943]    J: [ 32205.0841463]
# times: 240    J0: [ 32205.0841463]    J: [ 32205.0237965]
# times: 241    J0: [ 32205.0237965]    J: [ 32204.96377769]
# times: 242    J0: [ 32204.96377769]    J: [ 32204.90408758]
# times: 243    J0: [ 32204.90408758]    J: [ 32204.84472386]
# times: 244    J0: [ 32204.84472386]    J: [ 32204.78568427]
# times: 245    J0: [ 32204.78568427]    J: [ 32204.72696656]
# times: 246    J0: [ 32204.72696656]    J: [ 32204.66856848]
# times: 247    J0: [ 32204.66856848]    J: [ 32204.61048782]
# times: 248    J0: [ 32204.61048782]    J: [ 32204.55272238]
# times: 249    J0: [ 32204.55272238]    J: [ 32204.49526998]
# times: 250    J0: [ 32204.49526998]    J: [ 32204.43812846]
# times: 251    J0: [ 32204.43812846]    J: [ 32204.38129565]
# times: 252    J0: [ 32204.38129565]    J: [ 32204.32476944]
# times: 253    J0: [ 32204.32476944]    J: [ 32204.26854771]
# times: 254    J0: [ 32204.26854771]    J: [ 32204.21262837]
# times: 255    J0: [ 32204.21262837]    J: [ 32204.15700933]
# times: 256    J0: [ 32204.15700933]    J: [ 32204.10168853]
# times: 257    J0: [ 32204.10168853]    J: [ 32204.04666393]
# times: 258    J0: [ 32204.04666393]    J: [ 32203.99193349]
# times: 259    J0: [ 32203.99193349]    J: [ 32203.9374952]
# times: 260    J0: [ 32203.9374952]    J: [ 32203.88334706]
# times: 261    J0: [ 32203.88334706]    J: [ 32203.82948708]
# times: 262    J0: [ 32203.82948708]    J: [ 32203.77591331]
# times: 263    J0: [ 32203.77591331]    J: [ 32203.72262379]
# times: 264    J0: [ 32203.72262379]    J: [ 32203.66961658]
# times: 265    J0: [ 32203.66961658]    J: [ 32203.61688976]
# times: 266    J0: [ 32203.61688976]    J: [ 32203.56444142]
# times: 267    J0: [ 32203.56444142]    J: [ 32203.51226968]
# times: 268    J0: [ 32203.51226968]    J: [ 32203.46037266]
# times: 269    J0: [ 32203.46037266]    J: [ 32203.4087485]
# times: 270    J0: [ 32203.4087485]    J: [ 32203.35739535]
# times: 271    J0: [ 32203.35739535]    J: [ 32203.30631138]
# times: 272    J0: [ 32203.30631138]    J: [ 32203.25549477]
# times: 273    J0: [ 32203.25549477]    J: [ 32203.20494372]
# times: 274    J0: [ 32203.20494372]    J: [ 32203.15465644]
# times: 275    J0: [ 32203.15465644]    J: [ 32203.10463114]
# times: 276    J0: [ 32203.10463114]    J: [ 32203.05486608]
# times: 277    J0: [ 32203.05486608]    J: [ 32203.00535951]
# times: 278    J0: [ 32203.00535951]    J: [ 32202.95610968]
# times: 279    J0: [ 32202.95610968]    J: [ 32202.90711487]
# times: 280    J0: [ 32202.90711487]    J: [ 32202.85837339]
# times: 281    J0: [ 32202.85837339]    J: [ 32202.80988353]
# times: 282    J0: [ 32202.80988353]    J: [ 32202.76164362]
# times: 283    J0: [ 32202.76164362]    J: [ 32202.71365198]
# times: 284    J0: [ 32202.71365198]    J: [ 32202.66590696]
# times: 285    J0: [ 32202.66590696]    J: [ 32202.61840692]
# times: 286    J0: [ 32202.61840692]    J: [ 32202.57115022]
# times: 287    J0: [ 32202.57115022]    J: [ 32202.52413526]
# times: 288    J0: [ 32202.52413526]    J: [ 32202.47736042]
# times: 289    J0: [ 32202.47736042]    J: [ 32202.43082411]
# times: 290    J0: [ 32202.43082411]    J: [ 32202.38452476]
# times: 291    J0: [ 32202.38452476]    J: [ 32202.33846079]
# times: 292    J0: [ 32202.33846079]    J: [ 32202.29263065]
# times: 293    J0: [ 32202.29263065]    J: [ 32202.24703279]
# times: 294    J0: [ 32202.24703279]    J: [ 32202.20166568]
# times: 295    J0: [ 32202.20166568]    J: [ 32202.1565278]
# times: 296    J0: [ 32202.1565278]    J: [ 32202.11161764]
# times: 297    J0: [ 32202.11161764]    J: [ 32202.0669337]
# times: 298    J0: [ 32202.0669337]    J: [ 32202.0224745]
# times: 299    J0: [ 32202.0224745]    J: [ 32201.97823857]
# times: 0    J0: [ 35753.08871372]    J: [ 35752.76971431]
# times: 1    J0: [ 35752.76971431]    J: [ 35752.45422721]
# times: 2    J0: [ 35752.45422721]    J: [ 35752.14220695]
# times: 3    J0: [ 35752.14220695]    J: [ 35751.83360873]
# times: 4    J0: [ 35751.83360873]    J: [ 35751.52838845]
# times: 5    J0: [ 35751.52838845]    J: [ 35751.22650268]
# times: 6    J0: [ 35751.22650268]    J: [ 35750.92790863]
# times: 7    J0: [ 35750.92790863]    J: [ 35750.63256417]
# times: 8    J0: [ 35750.63256417]    J: [ 35750.3404278]
# times: 9    J0: [ 35750.3404278]    J: [ 35750.05145863]
# times: 10    J0: [ 35750.05145863]    J: [ 35749.76561639]
# times: 11    J0: [ 35749.76561639]    J: [ 35749.48286143]
# times: 12    J0: [ 35749.48286143]    J: [ 35749.20315465]
# times: 13    J0: [ 35749.20315465]    J: [ 35748.92645757]
# times: 14    J0: [ 35748.92645757]    J: [ 35748.65273223]
# times: 15    J0: [ 35748.65273223]    J: [ 35748.38194128]
# times: 16    J0: [ 35748.38194128]    J: [ 35748.11404788]
# times: 17    J0: [ 35748.11404788]    J: [ 35747.84901575]
# times: 18    J0: [ 35747.84901575]    J: [ 35747.58680913]
# times: 19    J0: [ 35747.58680913]    J: [ 35747.3273928]
# times: 20    J0: [ 35747.3273928]    J: [ 35747.07073201]
# times: 21    J0: [ 35747.07073201]    J: [ 35746.81679256]
# times: 22    J0: [ 35746.81679256]    J: [ 35746.56554072]
# times: 23    J0: [ 35746.56554072]    J: [ 35746.31694325]
# times: 24    J0: [ 35746.31694325]    J: [ 35746.07096737]
# times: 25    J0: [ 35746.07096737]    J: [ 35745.82758081]
# times: 26    J0: [ 35745.82758081]    J: [ 35745.58675172]
# times: 27    J0: [ 35745.58675172]    J: [ 35745.34844874]
# times: 28    J0: [ 35745.34844874]    J: [ 35745.11264091]
# times: 29    J0: [ 35745.11264091]    J: [ 35744.87929776]
# times: 30    J0: [ 35744.87929776]    J: [ 35744.64838922]
# times: 31    J0: [ 35744.64838922]    J: [ 35744.41988565]
# times: 32    J0: [ 35744.41988565]    J: [ 35744.19375783]
# times: 33    J0: [ 35744.19375783]    J: [ 35743.96997695]
# times: 34    J0: [ 35743.96997695]    J: [ 35743.7485146]
# times: 35    J0: [ 35743.7485146]    J: [ 35743.52934277]
# times: 36    J0: [ 35743.52934277]    J: [ 35743.31243384]
# times: 37    J0: [ 35743.31243384]    J: [ 35743.09776056]
# times: 38    J0: [ 35743.09776056]    J: [ 35742.8852961]
# times: 39    J0: [ 35742.8852961]    J: [ 35742.67501394]
# times: 40    J0: [ 35742.67501394]    J: [ 35742.46688799]
# times: 41    J0: [ 35742.46688799]    J: [ 35742.26089246]
# times: 42    J0: [ 35742.26089246]    J: [ 35742.05700196]
# times: 43    J0: [ 35742.05700196]    J: [ 35741.85519142]
# times: 44    J0: [ 35741.85519142]    J: [ 35741.65543613]
# times: 45    J0: [ 35741.65543613]    J: [ 35741.45771171]
# times: 46    J0: [ 35741.45771171]    J: [ 35741.2619941]
# times: 47    J0: [ 35741.2619941]    J: [ 35741.06825959]
# times: 48    J0: [ 35741.06825959]    J: [ 35740.87648478]
# times: 49    J0: [ 35740.87648478]    J: [ 35740.68664659]
# times: 50    J0: [ 35740.68664659]    J: [ 35740.49872223]
# times: 51    J0: [ 35740.49872223]    J: [ 35740.31268926]
# times: 52    J0: [ 35740.31268926]    J: [ 35740.12852549]
# times: 53    J0: [ 35740.12852549]    J: [ 35739.94620908]
# times: 54    J0: [ 35739.94620908]    J: [ 35739.76571843]
# times: 55    J0: [ 35739.76571843]    J: [ 35739.58703228]
# times: 56    J0: [ 35739.58703228]    J: [ 35739.4101296]
# times: 57    J0: [ 35739.4101296]    J: [ 35739.23498969]
# times: 58    J0: [ 35739.23498969]    J: [ 35739.0615921]
# times: 59    J0: [ 35739.0615921]    J: [ 35738.88991663]
# times: 60    J0: [ 35738.88991663]    J: [ 35738.7199434]
# times: 61    J0: [ 35738.7199434]    J: [ 35738.55165274]
# times: 62    J0: [ 35738.55165274]    J: [ 35738.38502526]
# times: 63    J0: [ 35738.38502526]    J: [ 35738.22004184]
# times: 64    J0: [ 35738.22004184]    J: [ 35738.05668358]
# times: 65    J0: [ 35738.05668358]    J: [ 35737.89493186]
# times: 66    J0: [ 35737.89493186]    J: [ 35737.73476826]
# times: 67    J0: [ 35737.73476826]    J: [ 35737.57617465]
# times: 68    J0: [ 35737.57617465]    J: [ 35737.41913311]
# times: 69    J0: [ 35737.41913311]    J: [ 35737.26362593]
# times: 70    J0: [ 35737.26362593]    J: [ 35737.10963568]
# times: 71    J0: [ 35737.10963568]    J: [ 35736.95714512]
# times: 72    J0: [ 35736.95714512]    J: [ 35736.80613723]
# times: 73    J0: [ 35736.80613723]    J: [ 35736.65659524]
# times: 74    J0: [ 35736.65659524]    J: [ 35736.50850257]
# times: 75    J0: [ 35736.50850257]    J: [ 35736.36184285]
# times: 76    J0: [ 35736.36184285]    J: [ 35736.21659993]
# times: 77    J0: [ 35736.21659993]    J: [ 35736.07275788]
# times: 78    J0: [ 35736.07275788]    J: [ 35735.93030094]
# times: 79    J0: [ 35735.93030094]    J: [ 35735.78921358]
# times: 80    J0: [ 35735.78921358]    J: [ 35735.64948046]
# times: 81    J0: [ 35735.64948046]    J: [ 35735.51108642]
# times: 82    J0: [ 35735.51108642]    J: [ 35735.37401651]
# times: 83    J0: [ 35735.37401651]    J: [ 35735.23825596]
# times: 84    J0: [ 35735.23825596]    J: [ 35735.10379019]
# times: 85    J0: [ 35735.10379019]    J: [ 35734.97060481]
# times: 86    J0: [ 35734.97060481]    J: [ 35734.8386856]
# times: 87    J0: [ 35734.8386856]    J: [ 35734.70801852]
# times: 88    J0: [ 35734.70801852]    J: [ 35734.57858971]
# times: 89    J0: [ 35734.57858971]    J: [ 35734.45038548]
# times: 90    J0: [ 35734.45038548]    J: [ 35734.32339232]
# times: 91    J0: [ 35734.32339232]    J: [ 35734.19759687]
# times: 92    J0: [ 35734.19759687]    J: [ 35734.07298597]
# times: 93    J0: [ 35734.07298597]    J: [ 35733.94954658]
# times: 94    J0: [ 35733.94954658]    J: [ 35733.82726585]
# times: 95    J0: [ 35733.82726585]    J: [ 35733.70613109]
# times: 96    J0: [ 35733.70613109]    J: [ 35733.58612976]
# times: 97    J0: [ 35733.58612976]    J: [ 35733.46724947]
# times: 98    J0: [ 35733.46724947]    J: [ 35733.34947799]
# times: 99    J0: [ 35733.34947799]    J: [ 35733.23280323]
# times: 100    J0: [ 35733.23280323]    J: [ 35733.11721328]
# times: 101    J0: [ 35733.11721328]    J: [ 35733.00269633]
# times: 102    J0: [ 35733.00269633]    J: [ 35732.88924075]
# times: 103    J0: [ 35732.88924075]    J: [ 35732.77683503]
# times: 104    J0: [ 35732.77683503]    J: [ 35732.66546783]
# times: 105    J0: [ 35732.66546783]    J: [ 35732.55512791]
# times: 106    J0: [ 35732.55512791]    J: [ 35732.4458042]
# times: 107    J0: [ 35732.4458042]    J: [ 35732.33748575]
# times: 108    J0: [ 35732.33748575]    J: [ 35732.23016173]
# times: 109    J0: [ 35732.23016173]    J: [ 35732.12382147]
# times: 110    J0: [ 35732.12382147]    J: [ 35732.01845441]
# times: 111    J0: [ 35732.01845441]    J: [ 35731.91405012]
# times: 112    J0: [ 35731.91405012]    J: [ 35731.8105983]
# times: 113    J0: [ 35731.8105983]    J: [ 35731.70808877]
# times: 114    J0: [ 35731.70808877]    J: [ 35731.60651148]
# times: 115    J0: [ 35731.60651148]    J: [ 35731.50585648]
# times: 116    J0: [ 35731.50585648]    J: [ 35731.40611398]
# times: 164    J0: [ 35727.59073103]    J: [ 35727.52523029]
# times: 165    J0: [ 35727.52523029]    J: [ 35727.4602789]
# times: 166    J0: [ 35727.4602789]    J: [ 35727.39587138]
# times: 167    J0: [ 35727.39587138]    J: [ 35727.3320023]
# times: 168    J0: [ 35727.3320023]    J: [ 35727.2686663]
# times: 169    J0: [ 35727.2686663]    J: [ 35727.20585809]
# times: 170    J0: [ 35727.20585809]    J: [ 35727.14357241]
# times: 171    J0: [ 35727.14357241]    J: [ 35727.0818041]
# times: 172    J0: [ 35727.0818041]    J: [ 35727.02054801]
# times: 173    J0: [ 35727.02054801]    J: [ 35726.95979909]
# times: 174    J0: [ 35726.95979909]    J: [ 35726.89955232]
# times: 175    J0: [ 35726.89955232]    J: [ 35726.83980275]
# times: 176    J0: [ 35726.83980275]    J: [ 35726.78054547]
# times: 177    J0: [ 35726.78054547]    J: [ 35726.72177564]
# times: 178    J0: [ 35726.72177564]    J: [ 35726.66348846]
# times: 179    J0: [ 35726.66348846]    J: [ 35726.60567919]
# times: 180    J0: [ 35726.60567919]    J: [ 35726.54834314]
# times: 181    J0: [ 35726.54834314]    J: [ 35726.49147568]
# times: 182    J0: [ 35726.49147568]    J: [ 35726.43507221]
# times: 183    J0: [ 35726.43507221]    J: [ 35726.37912821]
# times: 184    J0: [ 35726.37912821]    J: [ 35726.32363918]
# times: 185    J0: [ 35726.32363918]    J: [ 35726.2686007]
# times: 186    J0: [ 35726.2686007]    J: [ 35726.21400836]
# times: 187    J0: [ 35726.21400836]    J: [ 35726.15985784]
# times: 188    J0: [ 35726.15985784]    J: [ 35726.10614484]
# times: 189    J0: [ 35726.10614484]    J: [ 35726.0528651]
# times: 190    J0: [ 35726.0528651]    J: [ 35726.00001444]
# times: 191    J0: [ 35726.00001444]    J: [ 35725.94758869]
# times: 192    J0: [ 35725.94758869]    J: [ 35725.89558376]
# times: 193    J0: [ 35725.89558376]    J: [ 35725.84399556]
# times: 194    J0: [ 35725.84399556]    J: [ 35725.79282009]
# times: 195    J0: [ 35725.79282009]    J: [ 35725.74205337]
# times: 196    J0: [ 35725.74205337]    J: [ 35725.69169145]
# times: 197    J0: [ 35725.69169145]    J: [ 35725.64173046]
# times: 198    J0: [ 35725.64173046]    J: [ 35725.59216654]
# times: 199    J0: [ 35725.59216654]    J: [ 35725.54299588]
# times: 200    J0: [ 35725.54299588]    J: [ 35725.49421471]
# times: 201    J0: [ 35725.49421471]    J: [ 35725.44581932]
# times: 202    J0: [ 35725.44581932]    J: [ 35725.397806]
# times: 203    J0: [ 35725.397806]    J: [ 35725.35017113]
# times: 204    J0: [ 35725.35017113]    J: [ 35725.30291107]
# times: 205    J0: [ 35725.30291107]    J: [ 35725.25602228]
# times: 206    J0: [ 35725.25602228]    J: [ 35725.20950122]
# times: 207    J0: [ 35725.20950122]    J: [ 35725.16334438]
# times: 208    J0: [ 35725.16334438]    J: [ 35725.11754833]
# times: 209    J0: [ 35725.11754833]    J: [ 35725.07210963]
# times: 210    J0: [ 35725.07210963]    J: [ 35725.0270249]
# times: 211    J0: [ 35725.0270249]    J: [ 35724.98229081]
# times: 212    J0: [ 35724.98229081]    J: [ 35724.93790403]
# times: 213    J0: [ 35724.93790403]    J: [ 35724.89386129]
# times: 214    J0: [ 35724.89386129]    J: [ 35724.85015934]
# times: 215    J0: [ 35724.85015934]    J: [ 35724.80679499]
# times: 216    J0: [ 35724.80679499]    J: [ 35724.76376505]
# times: 217    J0: [ 35724.76376505]    J: [ 35724.72106639]
# times: 218    J0: [ 35724.72106639]    J: [ 35724.6786959]
# times: 219    J0: [ 35724.6786959]    J: [ 35724.6366505]
# times: 220    J0: [ 35724.6366505]    J: [ 35724.59492716]
# times: 221    J0: [ 35724.59492716]    J: [ 35724.55352286]
# times: 222    J0: [ 35724.55352286]    J: [ 35724.51243462]
# times: 223    J0: [ 35724.51243462]    J: [ 35724.4716595]
# times: 224    J0: [ 35724.4716595]    J: [ 35724.43119459]
# times: 225    J0: [ 35724.43119459]    J: [ 35724.39103699]
# times: 226    J0: [ 35724.39103699]    J: [ 35724.35118384]
# times: 227    J0: [ 35724.35118384]    J: [ 35724.31163234]
# times: 228    J0: [ 35724.31163234]    J: [ 35724.27237967]
# times: 229    J0: [ 35724.27237967]    J: [ 35724.23342307]
# times: 230    J0: [ 35724.23342307]    J: [ 35724.1947598]
# times: 231    J0: [ 35724.1947598]    J: [ 35724.15638716]
# times: 232    J0: [ 35724.15638716]    J: [ 35724.11830245]
# times: 233    J0: [ 35724.11830245]    J: [ 35724.08050303]
# times: 234    J0: [ 35724.08050303]    J: [ 35724.04298627]
# times: 235    J0: [ 35724.04298627]    J: [ 35724.00574957]
# times: 236    J0: [ 35724.00574957]    J: [ 35723.96879036]
# times: 237    J0: [ 35723.96879036]    J: [ 35723.93210609]
# times: 238    J0: [ 35723.93210609]    J: [ 35723.89569424]
# times: 239    J0: [ 35723.89569424]    J: [ 35723.85955232]
# times: 240    J0: [ 35723.85955232]    J: [ 35723.82367785]
# times: 241    J0: [ 35723.82367785]    J: [ 35723.78806841]
# times: 242    J0: [ 35723.78806841]    J: [ 35723.75272156]
# times: 243    J0: [ 35723.75272156]    J: [ 35723.71763492]
# times: 244    J0: [ 35723.71763492]    J: [ 35723.68280611]
# times: 245    J0: [ 35723.68280611]    J: [ 35723.6482328]
# times: 246    J0: [ 35723.6482328]    J: [ 35723.61391266]
# times: 247    J0: [ 35723.61391266]    J: [ 35723.5798434]
# times: 248    J0: [ 35723.5798434]    J: [ 35723.54602274]
# times: 249    J0: [ 35723.54602274]    J: [ 35723.51244843]
# times: 250    J0: [ 35723.51244843]    J: [ 35723.47911825]
# times: 251    J0: [ 35723.47911825]    J: [ 35723.44602999]
# times: 252    J0: [ 35723.44602999]    J: [ 35723.41318147]
# times: 253    J0: [ 35723.41318147]    J: [ 35723.38057052]
# times: 254    J0: [ 35723.38057052]    J: [ 35723.34819502]
# times: 255    J0: [ 35723.34819502]    J: [ 35723.31605284]
# times: 256    J0: [ 35723.31605284]    J: [ 35723.28414189]
# times: 257    J0: [ 35723.28414189]    J: [ 35723.2524601]
# times: 258    J0: [ 35723.2524601]    J: [ 35723.22100541]
# times: 259    J0: [ 35723.22100541]    J: [ 35723.18977579]
# times: 260    J0: [ 35723.18977579]    J: [ 35723.15876923]
# times: 261    J0: [ 35723.15876923]    J: [ 35723.12798373]
# times: 262    J0: [ 35723.12798373]    J: [ 35723.09741733]
# times: 263    J0: [ 35723.09741733]    J: [ 35723.06706807]
# times: 264    J0: [ 35723.06706807]    J: [ 35723.03693402]
# times: 265    J0: [ 35723.03693402]    J: [ 35723.00701326]
# times: 266    J0: [ 35723.00701326]    J: [ 35722.97730392]
# times: 267    J0: [ 35722.97730392]    J: [ 35722.94780409]
# times: 268    J0: [ 35722.94780409]    J: [ 35722.91851195]
# times: 269    J0: [ 35722.91851195]    J: [ 35722.88942563]
# times: 270    J0: [ 35722.88942563]    J: [ 35722.86054333]
# times: 271    J0: [ 35722.86054333]    J: [ 35722.83186325]
# times: 272    J0: [ 35722.83186325]    J: [ 35722.80338359]
# times: 273    J0: [ 35722.80338359]    J: [ 35722.7751026]
# times: 274    J0: [ 35722.7751026]    J: [ 35722.74701852]
# times: 275    J0: [ 35722.74701852]    J: [ 35722.71912963]
# times: 276    J0: [ 35722.71912963]    J: [ 35722.69143421]
# times: 277    J0: [ 35722.69143421]    J: [ 35722.66393056]
# times: 278    J0: [ 35722.66393056]    J: [ 35722.63661701]
# times: 279    J0: [ 35722.63661701]    J: [ 35722.60949188]
# times: 280    J0: [ 35722.60949188]    J: [ 35722.58255354]
# times: 281    J0: [ 35722.58255354]    J: [ 35722.55580036]
# times: 282    J0: [ 35722.55580036]    J: [ 35722.5292307]
# times: 283    J0: [ 35722.5292307]    J: [ 35722.50284299]
# times: 284    J0: [ 35722.50284299]    J: [ 35722.47663563]
# times: 285    J0: [ 35722.47663563]    J: [ 35722.45060706]
# times: 286    J0: [ 35722.45060706]    J: [ 35722.42475572]
# times: 287    J0: [ 35722.42475572]    J: [ 35722.39908007]
# times: 288    J0: [ 35722.39908007]    J: [ 35722.3735786]
# times: 289    J0: [ 35722.3735786]    J: [ 35722.3482498]
# times: 290    J0: [ 35722.3482498]    J: [ 35722.32309217]
# times: 291    J0: [ 35722.32309217]    J: [ 35722.29810423]
# times: 292    J0: [ 35722.29810423]    J: [ 35722.27328453]
# times: 293    J0: [ 35722.27328453]    J: [ 35722.2486316]
# times: 294    J0: [ 35722.2486316]    J: [ 35722.22414402]
# times: 295    J0: [ 35722.22414402]    J: [ 35722.19982036]
# times: 296    J0: [ 35722.19982036]    J: [ 35722.17565922]
# times: 297    J0: [ 35722.17565922]    J: [ 35722.1516592]
# times: 298    J0: [ 35722.1516592]    J: [ 35722.12781892]
# times: 299    J0: [ 35722.12781892]    J: [ 35722.10413702]
# times: 0    J0: [ 34710.8509766]    J: [ 34710.54194124]
# times: 1    J0: [ 34710.54194124]    J: [ 34710.23664468]
# times: 2    J0: [ 34710.23664468]    J: [ 34709.93502452]
# times: 3    J0: [ 34709.93502452]    J: [ 34709.63701963]
# times: 238    J0: [ 34681.67123925]    J: [ 34681.62434473]
# times: 239    J0: [ 34681.62434473]    J: [ 34681.57768703]
# times: 240    J0: [ 34681.57768703]    J: [ 34681.53126412]
# times: 241    J0: [ 34681.53126412]    J: [ 34681.48507403]
# times: 242    J0: [ 34681.48507403]    J: [ 34681.43911479]
# times: 243    J0: [ 34681.43911479]    J: [ 34681.39338445]
# times: 244    J0: [ 34681.39338445]    J: [ 34681.34788109]
# times: 245    J0: [ 34681.34788109]    J: [ 34681.30260279]
# times: 246    J0: [ 34681.30260279]    J: [ 34681.25754767]
# times: 247    J0: [ 34681.25754767]    J: [ 34681.21271386]
# times: 248    J0: [ 34681.21271386]    J: [ 34681.1680995]
# times: 249    J0: [ 34681.1680995]    J: [ 34681.12370277]
# times: 250    J0: [ 34681.12370277]    J: [ 34681.07952186]
# times: 251    J0: [ 34681.07952186]    J: [ 34681.03555495]
# times: 252    J0: [ 34681.03555495]    J: [ 34680.99180028]
# times: 253    J0: [ 34680.99180028]    J: [ 34680.94825609]
# times: 254    J0: [ 34680.94825609]    J: [ 34680.90492063]
# times: 255    J0: [ 34680.90492063]    J: [ 34680.86179217]
# times: 256    J0: [ 34680.86179217]    J: [ 34680.81886902]
# times: 257    J0: [ 34680.81886902]    J: [ 34680.77614946]
# times: 258    J0: [ 34680.77614946]    J: [ 34680.73363184]
# times: 259    J0: [ 34680.73363184]    J: [ 34680.69131448]
# times: 260    J0: [ 34680.69131448]    J: [ 34680.64919575]
# times: 261    J0: [ 34680.64919575]    J: [ 34680.60727402]
# times: 262    J0: [ 34680.60727402]    J: [ 34680.56554767]
# times: 263    J0: [ 34680.56554767]    J: [ 34680.52401512]
# times: 264    J0: [ 34680.52401512]    J: [ 34680.48267479]
# times: 265    J0: [ 34680.48267479]    J: [ 34680.44152509]
# times: 266    J0: [ 34680.44152509]    J: [ 34680.4005645]
# times: 267    J0: [ 34680.4005645]    J: [ 34680.35979147]
# times: 268    J0: [ 34680.35979147]    J: [ 34680.31920449]
# times: 269    J0: [ 34680.31920449]    J: [ 34680.27880204]
# times: 270    J0: [ 34680.27880204]    J: [ 34680.23858264]
# times: 271    J0: [ 34680.23858264]    J: [ 34680.19854482]
# times: 272    J0: [ 34680.19854482]    J: [ 34680.1586871]
# times: 273    J0: [ 34680.1586871]    J: [ 34680.11900804]
# times: 274    J0: [ 34680.11900804]    J: [ 34680.07950621]
# times: 275    J0: [ 34680.07950621]    J: [ 34680.04018018]
# times: 276    J0: [ 34680.04018018]    J: [ 34680.00102855]
# times: 277    J0: [ 34680.00102855]    J: [ 34679.96204992]
# times: 278    J0: [ 34679.96204992]    J: [ 34679.92324292]
# times: 279    J0: [ 34679.92324292]    J: [ 34679.88460617]
# times: 280    J0: [ 34679.88460617]    J: [ 34679.84613832]
# times: 281    J0: [ 34679.84613832]    J: [ 34679.80783803]
# times: 282    J0: [ 34679.80783803]    J: [ 34679.76970396]
# times: 283    J0: [ 34679.76970396]    J: [ 34679.73173481]
# times: 284    J0: [ 34679.73173481]    J: [ 34679.69392926]
# times: 285    J0: [ 34679.69392926]    J: [ 34679.65628602]
# times: 286    J0: [ 34679.65628602]    J: [ 34679.61880382]
# times: 287    J0: [ 34679.61880382]    J: [ 34679.58148138]
# times: 288    J0: [ 34679.58148138]    J: [ 34679.54431745]
# times: 289    J0: [ 34679.54431745]    J: [ 34679.50731078]
# times: 290    J0: [ 34679.50731078]    J: [ 34679.47046014]
# times: 291    J0: [ 34679.47046014]    J: [ 34679.43376431]
# times: 292    J0: [ 34679.43376431]    J: [ 34679.39722207]
# times: 293    J0: [ 34679.39722207]    J: [ 34679.36083223]
# times: 294    J0: [ 34679.36083223]    J: [ 34679.3245936]
# times: 295    J0: [ 34679.3245936]    J: [ 34679.28850499]
# times: 296    J0: [ 34679.28850499]    J: [ 34679.25256525]
# times: 297    J0: [ 34679.25256525]    J: [ 34679.21677321]
# times: 298    J0: [ 34679.21677321]    J: [ 34679.18112774]
# times: 299    J0: [ 34679.18112774]    J: [ 34679.14562769]

# %%
pred_L = model_L.predict(va_x)
pred_M = model_M.predict(va_x)
pred_H = model_H.predict(va_x)
pred = np.concatenate((pred_L, pred_M, pred_H), axis=1)
_res = pred.argmax(axis=1)
res = numTolabel(_res)
check_label(res, vlabel)

# %%
# Out:
# 0.262

# %%
res
# Out:
# ['LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW',
#  'LOW']

# %%
def getset(dataset, voc_id):
    my_set = []
    dataset = set(dataset)
    for line in dataset:
        my_set += [list(map(lambda x: voc_id.index(x), set(line)&set(voc_id)))]
    return my_set
def check_label(res ,std):
    return (np.array(res) == np.array(std)).sum() / len(std)
class onehot(object):
    """docstring for Onehot"""
    def __init__(self, voc_id, label, Train_set, Test_set, sample, K=10):
        self.label = label
        self.pred = []
        if(sample == None):
            sample = len(Train_set)
        Train = []
        Label = []
        for i in sample:
            Train += [Train_set[i]]
            Label += [label[i]]
        for Test_item in Test_set:
            dist= list(map(lambda x:self.calc_distance(x, Test_item), Train))
            NN = sorted(zip(dist, Label), key=lambda x:x[0], reverse=True)
            self.pred += [Counter(list(map(lambda x:x[1], NN[:K]))).most_common(1)[0][0]]
        return 
    def calc_distance(self, a, b):
        epsilon = 0.0001
        c = [x for x in a if x in b]
#         dist = (len(c)*(len(a)+len(b)) / (2*len(a)*len(b)))**4
        dist = (2 * len(c) / (len(a) + len(b)))
        return 1 / (epsilon + dist)

# %%
sample = random.sample(range(len(train_set)), 10000)
Train_set = getset(train_set, voc_id)
Valid_set = getset(valid_set, voc_id)
model = onehot(voc_id, label, Train_set, Valid_set, sample)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-75789bc105b5> in <module>()
#       1 sample = random.sample(range(len(train_set)), 10000)
# ----> 2 Train_set = getset(train_set, voc_id)
#       3 Valid_set = getset(valid_set, voc_id)
#       4 model = onehot(voc_id, label, Train_set, Valid_set, sample)
#
# <ipython-input-9-a4967c35eead> in getset(dataset, voc_id)
#       1 def getset(dataset, voc_id):
#       2     my_set = []
# ----> 3     dataset = set(dataset)
#       4     for line in dataset:
#       5         my_set += [list(map(lambda x: voc_id.index(x), set(line)&set(voc_id)))]
#
# TypeError: unhashable type: 'Counter'
